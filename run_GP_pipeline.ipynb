# %% [markdown]
# # Peru SWAN Pipeline: End-to-End Run
# This notebook runs each major pipeline script in a separate cell.
#
# **Make sure to set your desired `RUN_PATH` in `config.py` before running.**
#
# ---

# %%
# 1. Data Preparation
# %env PYTHONPATH=.
# %env RUN_PATH=run_g8
# %env MIN_DAYS=1
# !python3 scripts/data_preparation_0.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g8
# env: MIN_DAYS=1
# ✅ Using centralized configuration
# 🔧 DATA_PREPARATION_0.PY - Initial Processing
# 🚀 DATA PREPARATION STEP 0 - INITIAL PROCESSING
# ================================================================================
# Run: run_g8
# Reference port: CALETA_NAZCA
# Coordinates: (-14.83, -75.09)
# ================================================================================
#
# 📊 STEP 1: Loading port closure data...
# ✅ Loaded 23073 port closure records
# Years: [np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024), np.int64(2025)]
# Ports: 150 unique ports
#
# 🌊 STEP 2: Loading SWAN wave data...
# Loading SWAN wave data from CSV...
# Loaded 36,017 wave data records
# Date range: 2013-01-01 to 2025-04-30
# SWH range: 0.775 to 4.290 m
#
# 📈 STEP 3: Processing SWAN data to daily aggregates...
# Processing SWAN data for CALETA_NAZCA...
# 60th percentile threshold from 2023: 1.82m
# ✅ SWAN daily processing complete: (2557, 30)
#
# 📡 STEP 4: Loading and processing WAVERYS data...
# Loading WAVERYS data for reference port: CALETA_NAZCA
# Processing WAVERYS 1993...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 1994...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 1995...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 1996...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 1997...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 1998...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 1999...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2000...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 2001...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2002...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2003...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2004...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 2005...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2006...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2007...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2008...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 2009...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2010...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2011...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2012...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 2013...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2014...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2015...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2016...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 2017...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2018...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2019...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2020...
#   Loaded 2,928 records for CALETA_NAZCA
# Processing WAVERYS 2021...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2022...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2023...
#   Loaded 2,920 records for CALETA_NAZCA
# Processing WAVERYS 2024...
#   Loaded 2,928 records for CALETA_NAZCA
# Calculating climatologies and anomalies...
# Merging with port closure data...
#
# WAVERYS dataset summary:
# Total records: 93,504
# Date range: 1993-01-01 to 2024-12-31
# Port: CALETA_NAZCA
# Processing WAVERYS data...
# 75th percentile threshold from 2023: 2.08m
# Creating event indicators from duration data...
# Total rows marked as events: 620
# Percentage of rows marked as events: 24.25%
# ✅ WAVERYS daily processing complete: (2557, 41)
#
# 💾 STEP 5: Saving processed files...
# ✅ Saved: df_swan_hourly.csv ((35057, 3))
# ✅ Saved: df_swan_daily_enhanced.csv ((2557, 30))
# ✅ Saved: df_waverys_hourly.csv ((93504, 25))
# ✅ Saved: df_waverys_daily.csv ((2557, 41))
#
# 🏷️ STEP 6: Creating renamed versions for pipeline...
# ✅ Saved: df_swan_daily_new_colnames.csv ((2557, 30))
# ✅ Saved: df_waverys_daily_new_colnames.csv ((2557, 35))
# ✅ data_preparation_0.py completed successfully!

# %%
# 1. Data Preparation
# %env PYTHONPATH=.
# %env RUN_PATH=run_g8
# %env MIN_DAYS=1
# !python3 scripts/data_preparation_1.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g8
# env: MIN_DAYS=1
# ✅ Using centralized configuration
#
# 🔧 DATA_PREPARATION_1.PY - Enhanced Processing
#
# STEP 1: Loading and validating daily data
# ✓ Loaded SWAN daily data: (2557, 30)
# ✓ Loaded WAVERYS data for CALETA_NAZCA: (2557, 41)
# SWAN data date range: 2018-01-01 to 2024-12-31
# WAVERYS data date range: 2018-01-01 to 2024-12-31
# WAVERYS ports: ['CALETA_NAZCA']
#
# STEP 2: Detrending and deseasonalizing reference point data
# Input data shape: (2557, 30)
# Apply detrending: True
# Apply deseasonalizing: True
# Processing 21 wave features...
# Example features: ['swh_mean', 'swh_max', 'swh_min', 'swh_median', 'swh_p80']
# Vectorized processing of 21 features...
#
# STEP 3: Enhanced feature engineering on reference point data
# Input shape: (2557, 73)
# Use processed features: True
# Creating enhanced features from 64 SWAN wave features features...
#   Creating moving average features (memory-efficient)...
#   Creating trend features (memory-efficient)...
#     Computing slopes for window 3...
#     Computing slopes for window 5...
#     Computing slopes for window 7...
#     Computing slopes for window 14...
#   Creating change features (memory-efficient)...
#   Creating lag features (memory-efficient)...
#     Creating lags for 1728 features...
#       Processing lag 1...
#       Processing lag 3...
#       Processing lag 5...
#       Processing lag 7...
#       Processing lag 14...
#   Lag features complete!
# Enhanced feature engineering complete:
#   Original features: 73
#   Enhanced features: 10377
#   New features created: 10304
#   Output shape: (2557, 10377)
#
# 📊 Example SWAN features created (before merge):
#   swh_max moving averages: 180 features
#     - anom_swh_max_deseasonalized_detrended_ma_14
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_1
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_14
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_3
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_5
#     ... and 175 more
#   All swh_ moving averages: 2286 features
#     - anom_swh_max_deseasonalized_detrended_ma_14
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_1
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_14
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_3
#     - anom_swh_max_deseasonalized_detrended_ma_14_lag_5
#     ... and 2281 more
#
# 💡 Note: After merge, these will become:
#     - swh_max_ma_7 → swh_max_ma_7_swan
#     - swh_max_trend_3 → swh_max_trend_3_swan
#     - swh_max_abs_change_3 → swh_max_abs_change_3_swan
#
# STEP 4: Adding _swan suffix to SWAN features
# ✅ Renamed 10376 SWAN features with _swan suffix
#   Example renames:
#     swh_mean → swh_mean_swan
#     swh_max → swh_max_swan
#     swh_min → swh_min_swan
#     swh_median → swh_median_swan
#     swh_p80 → swh_p80_swan
#     ... and 10371 more
#
# STEP 5: Merging with WAVERYS data
# Merged dataset shape: (2557, 10417)
# ✅ Saved: /Users/ageidv/suyana/peru_swan/wave_analysis_pipeline/data/processed/run_g8/df_swan_daily_features.csv ((2557, 10378))
# ✅ Saved: /Users/ageidv/suyana/peru_swan/wave_analysis_pipeline/data/processed/run_g8/df_swan_waverys_merged.csv ((2557, 10417))

# %%
# 2. Rule Evaluation (CV, ML, Thresholds)
# %env PYTHONPATH=.
# %env RUN_PATH=run_g8
# %env MIN_DAYS=1
# !python3 scripts/GP_rule_evaluation.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g8
# env: MIN_DAYS=1
#
# 🔧 SIMPLIFIED_RULE_EVALUATION.PY
# Run: run_g8
# Reference port: CALETA_NAZCA
# 🔎 Looking for merged features at: /Users/ageidv/suyana/peru_swan/wave_analysis_pipeline/data/processed/run_g8/df_swan_waverys_merged.csv
# ✅ Loaded merged features: /Users/ageidv/suyana/peru_swan/wave_analysis_pipeline/data/processed/run_g8/df_swan_waverys_merged.csv ((2557, 10417))
#
# ================================================================================
# 🔍 DEBUGGING FEATURE SELECTION
# ============================================================
# 🔍 Finding features that are SWAN-related AND contain MAX...
# ✅ Found 972 features (SWAN + MAX):
#    1. anom_swh_max_abs_change_14_lag_14_swan
#    2. anom_swh_max_abs_change_14_lag_1_swan
#    3. anom_swh_max_abs_change_14_lag_3_swan
#    4. anom_swh_max_abs_change_14_lag_5_swan
#    5. anom_swh_max_abs_change_14_lag_7_swan
#    6. anom_swh_max_abs_change_14_swan
#    7. anom_swh_max_abs_change_3_lag_14_swan
#    8. anom_swh_max_abs_change_3_lag_1_swan
#    9. anom_swh_max_abs_change_3_lag_3_swan
#   10. anom_swh_max_abs_change_3_lag_5_swan
#   11. anom_swh_max_abs_change_3_lag_7_swan
#   12. anom_swh_max_abs_change_3_swan
#   13. anom_swh_max_abs_change_5_lag_14_swan
#   14. anom_swh_max_abs_change_5_lag_1_swan
#   15. anom_swh_max_abs_change_5_lag_3_swan
#   16. anom_swh_max_abs_change_5_lag_5_swan
#   17. anom_swh_max_abs_change_5_lag_7_swan
#   18. anom_swh_max_abs_change_5_swan
#   19. anom_swh_max_abs_change_7_lag_14_swan
#   20. anom_swh_max_abs_change_7_lag_1_swan
#   21. anom_swh_max_abs_change_7_lag_3_swan
#   22. anom_swh_max_abs_change_7_lag_5_swan
#   23. anom_swh_max_abs_change_7_lag_7_swan
#   24. anom_swh_max_abs_change_7_swan
#   25. anom_swh_max_deseasonalized_abs_change_14_lag_14_swan
#   26. anom_swh_max_deseasonalized_abs_change_14_lag_1_swan
#   27. anom_swh_max_deseasonalized_abs_change_14_lag_3_swan
#   28. anom_swh_max_deseasonalized_abs_change_14_lag_5_swan
#   29. anom_swh_max_deseasonalized_abs_change_14_lag_7_swan
#   30. anom_swh_max_deseasonalized_abs_change_14_swan
#   31. anom_swh_max_deseasonalized_abs_change_3_lag_14_swan
#   32. anom_swh_max_deseasonalized_abs_change_3_lag_1_swan
#   33. anom_swh_max_deseasonalized_abs_change_3_lag_3_swan
#   34. anom_swh_max_deseasonalized_abs_change_3_lag_5_swan
#   35. anom_swh_max_deseasonalized_abs_change_3_lag_7_swan
#   36. anom_swh_max_deseasonalized_abs_change_3_swan
#   37. anom_swh_max_deseasonalized_abs_change_5_lag_14_swan
#   38. anom_swh_max_deseasonalized_abs_change_5_lag_1_swan
#   39. anom_swh_max_deseasonalized_abs_change_5_lag_3_swan
#   40. anom_swh_max_deseasonalized_abs_change_5_lag_5_swan
#   41. anom_swh_max_deseasonalized_abs_change_5_lag_7_swan
#   42. anom_swh_max_deseasonalized_abs_change_5_swan
#   43. anom_swh_max_deseasonalized_abs_change_7_lag_14_swan
#   44. anom_swh_max_deseasonalized_abs_change_7_lag_1_swan
#   45. anom_swh_max_deseasonalized_abs_change_7_lag_3_swan
#   46. anom_swh_max_deseasonalized_abs_change_7_lag_5_swan
#   47. anom_swh_max_deseasonalized_abs_change_7_lag_7_swan
#   48. anom_swh_max_deseasonalized_abs_change_7_swan
#   49. anom_swh_max_deseasonalized_detrended_abs_change_14_lag_14_swan
#   50. anom_swh_max_deseasonalized_detrended_abs_change_14_lag_1_swan
#   51. anom_swh_max_deseasonalized_detrended_abs_change_14_lag_3_swan
#   52. anom_swh_max_deseasonalized_detrended_abs_change_14_lag_5_swan
#   53. anom_swh_max_deseasonalized_detrended_abs_change_14_lag_7_swan
#   54. anom_swh_max_deseasonalized_detrended_abs_change_14_swan
#   55. anom_swh_max_deseasonalized_detrended_abs_change_3_lag_14_swan
#   56. anom_swh_max_deseasonalized_detrended_abs_change_3_lag_1_swan
#   57. anom_swh_max_deseasonalized_detrended_abs_change_3_lag_3_swan
#   58. anom_swh_max_deseasonalized_detrended_abs_change_3_lag_5_swan
#   59. anom_swh_max_deseasonalized_detrended_abs_change_3_lag_7_swan
#   60. anom_swh_max_deseasonalized_detrended_abs_change_3_swan
#   61. anom_swh_max_deseasonalized_detrended_abs_change_5_lag_14_swan
#   62. anom_swh_max_deseasonalized_detrended_abs_change_5_lag_1_swan
#   63. anom_swh_max_deseasonalized_detrended_abs_change_5_lag_3_swan
#   64. anom_swh_max_deseasonalized_detrended_abs_change_5_lag_5_swan
#   65. anom_swh_max_deseasonalized_detrended_abs_change_5_lag_7_swan
#   66. anom_swh_max_deseasonalized_detrended_abs_change_5_swan
#   67. anom_swh_max_deseasonalized_detrended_abs_change_7_lag_14_swan
#   68. anom_swh_max_deseasonalized_detrended_abs_change_7_lag_1_swan
#   69. anom_swh_max_deseasonalized_detrended_abs_change_7_lag_3_swan
#   70. anom_swh_max_deseasonalized_detrended_abs_change_7_lag_5_swan
#   71. anom_swh_max_deseasonalized_detrended_abs_change_7_lag_7_swan
#   72. anom_swh_max_deseasonalized_detrended_abs_change_7_swan
#   73. anom_swh_max_deseasonalized_detrended_lag_14_swan
#   74. anom_swh_max_deseasonalized_detrended_lag_1_swan
#   75. anom_swh_max_deseasonalized_detrended_lag_3_swan
#   76. anom_swh_max_deseasonalized_detrended_lag_5_swan
#   77. anom_swh_max_deseasonalized_detrended_lag_7_swan
#   78. anom_swh_max_deseasonalized_detrended_ma_14_lag_14_swan
#   79. anom_swh_max_deseasonalized_detrended_ma_14_lag_1_swan
#   80. anom_swh_max_deseasonalized_detrended_ma_14_lag_3_swan
#   81. anom_swh_max_deseasonalized_detrended_ma_14_lag_5_swan
#   82. anom_swh_max_deseasonalized_detrended_ma_14_lag_7_swan
#   83. anom_swh_max_deseasonalized_detrended_ma_14_swan
#   84. anom_swh_max_deseasonalized_detrended_ma_2_lag_14_swan
#   85. anom_swh_max_deseasonalized_detrended_ma_2_lag_1_swan
#   86. anom_swh_max_deseasonalized_detrended_ma_2_lag_3_swan
#   87. anom_swh_max_deseasonalized_detrended_ma_2_lag_5_swan
#   88. anom_swh_max_deseasonalized_detrended_ma_2_lag_7_swan
#   89. anom_swh_max_deseasonalized_detrended_ma_2_swan
#   90. anom_swh_max_deseasonalized_detrended_ma_3_lag_14_swan
#   91. anom_swh_max_deseasonalized_detrended_ma_3_lag_1_swan
#   92. anom_swh_max_deseasonalized_detrended_ma_3_lag_3_swan
#   93. anom_swh_max_deseasonalized_detrended_ma_3_lag_5_swan
#   94. anom_swh_max_deseasonalized_detrended_ma_3_lag_7_swan
#   95. anom_swh_max_deseasonalized_detrended_ma_3_swan
#   96. anom_swh_max_deseasonalized_detrended_ma_5_lag_14_swan
#   97. anom_swh_max_deseasonalized_detrended_ma_5_lag_1_swan
#   98. anom_swh_max_deseasonalized_detrended_ma_5_lag_3_swan
#   99. anom_swh_max_deseasonalized_detrended_ma_5_lag_5_swan
#   100. anom_swh_max_deseasonalized_detrended_ma_5_lag_7_swan
#   101. anom_swh_max_deseasonalized_detrended_ma_5_swan
#   102. anom_swh_max_deseasonalized_detrended_ma_7_lag_14_swan
#   103. anom_swh_max_deseasonalized_detrended_ma_7_lag_1_swan
#   104. anom_swh_max_deseasonalized_detrended_ma_7_lag_3_swan
#   105. anom_swh_max_deseasonalized_detrended_ma_7_lag_5_swan
#   106. anom_swh_max_deseasonalized_detrended_ma_7_lag_7_swan
#   107. anom_swh_max_deseasonalized_detrended_ma_7_swan
#   108. anom_swh_max_deseasonalized_detrended_persistence_14_lag_14_swan
#   109. anom_swh_max_deseasonalized_detrended_persistence_14_lag_1_swan
#   110. anom_swh_max_deseasonalized_detrended_persistence_14_lag_3_swan
#   111. anom_swh_max_deseasonalized_detrended_persistence_14_lag_5_swan
#   112. anom_swh_max_deseasonalized_detrended_persistence_14_lag_7_swan
#   113. anom_swh_max_deseasonalized_detrended_persistence_14_swan
#   114. anom_swh_max_deseasonalized_detrended_persistence_2_lag_14_swan
#   115. anom_swh_max_deseasonalized_detrended_persistence_2_lag_1_swan
#   116. anom_swh_max_deseasonalized_detrended_persistence_2_lag_3_swan
#   117. anom_swh_max_deseasonalized_detrended_persistence_2_lag_5_swan
#   118. anom_swh_max_deseasonalized_detrended_persistence_2_lag_7_swan
#   119. anom_swh_max_deseasonalized_detrended_persistence_2_swan
#   120. anom_swh_max_deseasonalized_detrended_persistence_3_lag_14_swan
#   121. anom_swh_max_deseasonalized_detrended_persistence_3_lag_1_swan
#   122. anom_swh_max_deseasonalized_detrended_persistence_3_lag_3_swan
#   123. anom_swh_max_deseasonalized_detrended_persistence_3_lag_5_swan
#   124. anom_swh_max_deseasonalized_detrended_persistence_3_lag_7_swan
#   125. anom_swh_max_deseasonalized_detrended_persistence_3_swan
#   126. anom_swh_max_deseasonalized_detrended_persistence_5_lag_14_swan
#   127. anom_swh_max_deseasonalized_detrended_persistence_5_lag_1_swan
#   128. anom_swh_max_deseasonalized_detrended_persistence_5_lag_3_swan
#   129. anom_swh_max_deseasonalized_detrended_persistence_5_lag_5_swan
#   130. anom_swh_max_deseasonalized_detrended_persistence_5_lag_7_swan
#   131. anom_swh_max_deseasonalized_detrended_persistence_5_swan
#   132. anom_swh_max_deseasonalized_detrended_persistence_7_lag_14_swan
#   133. anom_swh_max_deseasonalized_detrended_persistence_7_lag_1_swan
#   134. anom_swh_max_deseasonalized_detrended_persistence_7_lag_3_swan
#   135. anom_swh_max_deseasonalized_detrended_persistence_7_lag_5_swan
#   136. anom_swh_max_deseasonalized_detrended_persistence_7_lag_7_swan
#   137. anom_swh_max_deseasonalized_detrended_persistence_7_swan
#   138. anom_swh_max_deseasonalized_detrended_rel_change_14_lag_14_swan
#   139. anom_swh_max_deseasonalized_detrended_rel_change_14_lag_1_swan
#   140. anom_swh_max_deseasonalized_detrended_rel_change_14_lag_3_swan
#   141. anom_swh_max_deseasonalized_detrended_rel_change_14_lag_5_swan
#   142. anom_swh_max_deseasonalized_detrended_rel_change_14_lag_7_swan
#   143. anom_swh_max_deseasonalized_detrended_rel_change_14_swan
#   144. anom_swh_max_deseasonalized_detrended_rel_change_3_lag_14_swan
#   145. anom_swh_max_deseasonalized_detrended_rel_change_3_lag_1_swan
#   146. anom_swh_max_deseasonalized_detrended_rel_change_3_lag_3_swan
#   147. anom_swh_max_deseasonalized_detrended_rel_change_3_lag_5_swan
#   148. anom_swh_max_deseasonalized_detrended_rel_change_3_lag_7_swan
#   149. anom_swh_max_deseasonalized_detrended_rel_change_3_swan
#   150. anom_swh_max_deseasonalized_detrended_rel_change_5_lag_14_swan
#   151. anom_swh_max_deseasonalized_detrended_rel_change_5_lag_1_swan
#   152. anom_swh_max_deseasonalized_detrended_rel_change_5_lag_3_swan
#   153. anom_swh_max_deseasonalized_detrended_rel_change_5_lag_5_swan
#   154. anom_swh_max_deseasonalized_detrended_rel_change_5_lag_7_swan
#   155. anom_swh_max_deseasonalized_detrended_rel_change_5_swan
#   156. anom_swh_max_deseasonalized_detrended_rel_change_7_lag_14_swan
#   157. anom_swh_max_deseasonalized_detrended_rel_change_7_lag_1_swan
#   158. anom_swh_max_deseasonalized_detrended_rel_change_7_lag_3_swan
#   159. anom_swh_max_deseasonalized_detrended_rel_change_7_lag_5_swan
#   160. anom_swh_max_deseasonalized_detrended_rel_change_7_lag_7_swan
#   161. anom_swh_max_deseasonalized_detrended_rel_change_7_swan
#   162. anom_swh_max_deseasonalized_detrended_rolling_mean_14_lag_14_swan
#   163. anom_swh_max_deseasonalized_detrended_rolling_mean_14_lag_1_swan
#   164. anom_swh_max_deseasonalized_detrended_rolling_mean_14_lag_3_swan
#   165. anom_swh_max_deseasonalized_detrended_rolling_mean_14_lag_5_swan
#   166. anom_swh_max_deseasonalized_detrended_rolling_mean_14_lag_7_swan
#   167. anom_swh_max_deseasonalized_detrended_rolling_mean_14_swan
#   168. anom_swh_max_deseasonalized_detrended_rolling_mean_3_lag_14_swan
#   169. anom_swh_max_deseasonalized_detrended_rolling_mean_3_lag_1_swan
#   170. anom_swh_max_deseasonalized_detrended_rolling_mean_3_lag_3_swan
#   171. anom_swh_max_deseasonalized_detrended_rolling_mean_3_lag_5_swan
#   172. anom_swh_max_deseasonalized_detrended_rolling_mean_3_lag_7_swan
#   173. anom_swh_max_deseasonalized_detrended_rolling_mean_3_swan
#   174. anom_swh_max_deseasonalized_detrended_rolling_mean_5_lag_14_swan
#   175. anom_swh_max_deseasonalized_detrended_rolling_mean_5_lag_1_swan
#   176. anom_swh_max_deseasonalized_detrended_rolling_mean_5_lag_3_swan
#   177. anom_swh_max_deseasonalized_detrended_rolling_mean_5_lag_5_swan
#   178. anom_swh_max_deseasonalized_detrended_rolling_mean_5_lag_7_swan
#   179. anom_swh_max_deseasonalized_detrended_rolling_mean_5_swan
#   180. anom_swh_max_deseasonalized_detrended_rolling_mean_7_lag_14_swan
#   181. anom_swh_max_deseasonalized_detrended_rolling_mean_7_lag_1_swan
#   182. anom_swh_max_deseasonalized_detrended_rolling_mean_7_lag_3_swan
#   183. anom_swh_max_deseasonalized_detrended_rolling_mean_7_lag_5_swan
#   184. anom_swh_max_deseasonalized_detrended_rolling_mean_7_lag_7_swan
#   185. anom_swh_max_deseasonalized_detrended_rolling_mean_7_swan
#   186. anom_swh_max_deseasonalized_detrended_swan
#   187. anom_swh_max_deseasonalized_detrended_trend_14_lag_14_swan
#   188. anom_swh_max_deseasonalized_detrended_trend_14_lag_1_swan
#   189. anom_swh_max_deseasonalized_detrended_trend_14_lag_3_swan
#   190. anom_swh_max_deseasonalized_detrended_trend_14_lag_5_swan
#   191. anom_swh_max_deseasonalized_detrended_trend_14_lag_7_swan
#   192. anom_swh_max_deseasonalized_detrended_trend_14_swan
#   193. anom_swh_max_deseasonalized_detrended_trend_3_lag_14_swan
#   194. anom_swh_max_deseasonalized_detrended_trend_3_lag_1_swan
#   195. anom_swh_max_deseasonalized_detrended_trend_3_lag_3_swan
#   196. anom_swh_max_deseasonalized_detrended_trend_3_lag_5_swan
#   197. anom_swh_max_deseasonalized_detrended_trend_3_lag_7_swan
#   198. anom_swh_max_deseasonalized_detrended_trend_3_swan
#   199. anom_swh_max_deseasonalized_detrended_trend_5_lag_14_swan
#   200. anom_swh_max_deseasonalized_detrended_trend_5_lag_1_swan
#   201. anom_swh_max_deseasonalized_detrended_trend_5_lag_3_swan
#   202. anom_swh_max_deseasonalized_detrended_trend_5_lag_5_swan
#   203. anom_swh_max_deseasonalized_detrended_trend_5_lag_7_swan
#   204. anom_swh_max_deseasonalized_detrended_trend_5_swan
#   205. anom_swh_max_deseasonalized_detrended_trend_7_lag_14_swan
#   206. anom_swh_max_deseasonalized_detrended_trend_7_lag_1_swan
#   207. anom_swh_max_deseasonalized_detrended_trend_7_lag_3_swan
#   208. anom_swh_max_deseasonalized_detrended_trend_7_lag_5_swan
#   209. anom_swh_max_deseasonalized_detrended_trend_7_lag_7_swan
#   210. anom_swh_max_deseasonalized_detrended_trend_7_swan
#   211. anom_swh_max_deseasonalized_lag_14_swan
#   212. anom_swh_max_deseasonalized_lag_1_swan
#   213. anom_swh_max_deseasonalized_lag_3_swan
#   214. anom_swh_max_deseasonalized_lag_5_swan
#   215. anom_swh_max_deseasonalized_lag_7_swan
#   216. anom_swh_max_deseasonalized_ma_14_lag_14_swan
#   217. anom_swh_max_deseasonalized_ma_14_lag_1_swan
#   218. anom_swh_max_deseasonalized_ma_14_lag_3_swan
#   219. anom_swh_max_deseasonalized_ma_14_lag_5_swan
#   220. anom_swh_max_deseasonalized_ma_14_lag_7_swan
#   221. anom_swh_max_deseasonalized_ma_14_swan
#   222. anom_swh_max_deseasonalized_ma_2_lag_14_swan
#   223. anom_swh_max_deseasonalized_ma_2_lag_1_swan
#   224. anom_swh_max_deseasonalized_ma_2_lag_3_swan
#   225. anom_swh_max_deseasonalized_ma_2_lag_5_swan
#   226. anom_swh_max_deseasonalized_ma_2_lag_7_swan
#   227. anom_swh_max_deseasonalized_ma_2_swan
#   228. anom_swh_max_deseasonalized_ma_3_lag_14_swan
#   229. anom_swh_max_deseasonalized_ma_3_lag_1_swan
#   230. anom_swh_max_deseasonalized_ma_3_lag_3_swan
#   231. anom_swh_max_deseasonalized_ma_3_lag_5_swan
#   232. anom_swh_max_deseasonalized_ma_3_lag_7_swan
#   233. anom_swh_max_deseasonalized_ma_3_swan
#   234. anom_swh_max_deseasonalized_ma_5_lag_14_swan
#   235. anom_swh_max_deseasonalized_ma_5_lag_1_swan
#   236. anom_swh_max_deseasonalized_ma_5_lag_3_swan
#   237. anom_swh_max_deseasonalized_ma_5_lag_5_swan
#   238. anom_swh_max_deseasonalized_ma_5_lag_7_swan
#   239. anom_swh_max_deseasonalized_ma_5_swan
#   240. anom_swh_max_deseasonalized_ma_7_lag_14_swan
#   241. anom_swh_max_deseasonalized_ma_7_lag_1_swan
#   242. anom_swh_max_deseasonalized_ma_7_lag_3_swan
#   243. anom_swh_max_deseasonalized_ma_7_lag_5_swan
#   244. anom_swh_max_deseasonalized_ma_7_lag_7_swan
#   245. anom_swh_max_deseasonalized_ma_7_swan
#   246. anom_swh_max_deseasonalized_persistence_14_lag_14_swan
#   247. anom_swh_max_deseasonalized_persistence_14_lag_1_swan
#   248. anom_swh_max_deseasonalized_persistence_14_lag_3_swan
#   249. anom_swh_max_deseasonalized_persistence_14_lag_5_swan
#   250. anom_swh_max_deseasonalized_persistence_14_lag_7_swan
#   251. anom_swh_max_deseasonalized_persistence_14_swan
#   252. anom_swh_max_deseasonalized_persistence_2_lag_14_swan
#   253. anom_swh_max_deseasonalized_persistence_2_lag_1_swan
#   254. anom_swh_max_deseasonalized_persistence_2_lag_3_swan
#   255. anom_swh_max_deseasonalized_persistence_2_lag_5_swan
#   256. anom_swh_max_deseasonalized_persistence_2_lag_7_swan
#   257. anom_swh_max_deseasonalized_persistence_2_swan
#   258. anom_swh_max_deseasonalized_persistence_3_lag_14_swan
#   259. anom_swh_max_deseasonalized_persistence_3_lag_1_swan
#   260. anom_swh_max_deseasonalized_persistence_3_lag_3_swan
#   261. anom_swh_max_deseasonalized_persistence_3_lag_5_swan
#   262. anom_swh_max_deseasonalized_persistence_3_lag_7_swan
#   263. anom_swh_max_deseasonalized_persistence_3_swan
#   264. anom_swh_max_deseasonalized_persistence_5_lag_14_swan
#   265. anom_swh_max_deseasonalized_persistence_5_lag_1_swan
#   266. anom_swh_max_deseasonalized_persistence_5_lag_3_swan
#   267. anom_swh_max_deseasonalized_persistence_5_lag_5_swan
#   268. anom_swh_max_deseasonalized_persistence_5_lag_7_swan
#   269. anom_swh_max_deseasonalized_persistence_5_swan
#   270. anom_swh_max_deseasonalized_persistence_7_lag_14_swan
#   271. anom_swh_max_deseasonalized_persistence_7_lag_1_swan
#   272. anom_swh_max_deseasonalized_persistence_7_lag_3_swan
#   273. anom_swh_max_deseasonalized_persistence_7_lag_5_swan
#   274. anom_swh_max_deseasonalized_persistence_7_lag_7_swan
#   275. anom_swh_max_deseasonalized_persistence_7_swan
#   276. anom_swh_max_deseasonalized_rel_change_14_lag_14_swan
#   277. anom_swh_max_deseasonalized_rel_change_14_lag_1_swan
#   278. anom_swh_max_deseasonalized_rel_change_14_lag_3_swan
#   279. anom_swh_max_deseasonalized_rel_change_14_lag_5_swan
#   280. anom_swh_max_deseasonalized_rel_change_14_lag_7_swan
#   281. anom_swh_max_deseasonalized_rel_change_14_swan
#   282. anom_swh_max_deseasonalized_rel_change_3_lag_14_swan
#   283. anom_swh_max_deseasonalized_rel_change_3_lag_1_swan
#   284. anom_swh_max_deseasonalized_rel_change_3_lag_3_swan
#   285. anom_swh_max_deseasonalized_rel_change_3_lag_5_swan
#   286. anom_swh_max_deseasonalized_rel_change_3_lag_7_swan
#   287. anom_swh_max_deseasonalized_rel_change_3_swan
#   288. anom_swh_max_deseasonalized_rel_change_5_lag_14_swan
#   289. anom_swh_max_deseasonalized_rel_change_5_lag_1_swan
#   290. anom_swh_max_deseasonalized_rel_change_5_lag_3_swan
#   291. anom_swh_max_deseasonalized_rel_change_5_lag_5_swan
#   292. anom_swh_max_deseasonalized_rel_change_5_lag_7_swan
#   293. anom_swh_max_deseasonalized_rel_change_5_swan
#   294. anom_swh_max_deseasonalized_rel_change_7_lag_14_swan
#   295. anom_swh_max_deseasonalized_rel_change_7_lag_1_swan
#   296. anom_swh_max_deseasonalized_rel_change_7_lag_3_swan
#   297. anom_swh_max_deseasonalized_rel_change_7_lag_5_swan
#   298. anom_swh_max_deseasonalized_rel_change_7_lag_7_swan
#   299. anom_swh_max_deseasonalized_rel_change_7_swan
#   300. anom_swh_max_deseasonalized_rolling_mean_14_lag_14_swan
#   301. anom_swh_max_deseasonalized_rolling_mean_14_lag_1_swan
#   302. anom_swh_max_deseasonalized_rolling_mean_14_lag_3_swan
#   303. anom_swh_max_deseasonalized_rolling_mean_14_lag_5_swan
#   304. anom_swh_max_deseasonalized_rolling_mean_14_lag_7_swan
#   305. anom_swh_max_deseasonalized_rolling_mean_14_swan
#   306. anom_swh_max_deseasonalized_rolling_mean_3_lag_14_swan
#   307. anom_swh_max_deseasonalized_rolling_mean_3_lag_1_swan
#   308. anom_swh_max_deseasonalized_rolling_mean_3_lag_3_swan
#   309. anom_swh_max_deseasonalized_rolling_mean_3_lag_5_swan
#   310. anom_swh_max_deseasonalized_rolling_mean_3_lag_7_swan
#   311. anom_swh_max_deseasonalized_rolling_mean_3_swan
#   312. anom_swh_max_deseasonalized_rolling_mean_5_lag_14_swan
#   313. anom_swh_max_deseasonalized_rolling_mean_5_lag_1_swan
#   314. anom_swh_max_deseasonalized_rolling_mean_5_lag_3_swan
#   315. anom_swh_max_deseasonalized_rolling_mean_5_lag_5_swan
#   316. anom_swh_max_deseasonalized_rolling_mean_5_lag_7_swan
#   317. anom_swh_max_deseasonalized_rolling_mean_5_swan
#   318. anom_swh_max_deseasonalized_rolling_mean_7_lag_14_swan
#   319. anom_swh_max_deseasonalized_rolling_mean_7_lag_1_swan
#   320. anom_swh_max_deseasonalized_rolling_mean_7_lag_3_swan
#   321. anom_swh_max_deseasonalized_rolling_mean_7_lag_5_swan
#   322. anom_swh_max_deseasonalized_rolling_mean_7_lag_7_swan
#   323. anom_swh_max_deseasonalized_rolling_mean_7_swan
#   324. anom_swh_max_deseasonalized_swan
#   325. anom_swh_max_deseasonalized_trend_14_lag_14_swan
#   326. anom_swh_max_deseasonalized_trend_14_lag_1_swan
#   327. anom_swh_max_deseasonalized_trend_14_lag_3_swan
#   328. anom_swh_max_deseasonalized_trend_14_lag_5_swan
#   329. anom_swh_max_deseasonalized_trend_14_lag_7_swan
#   330. anom_swh_max_deseasonalized_trend_14_swan
#   331. anom_swh_max_deseasonalized_trend_3_lag_14_swan
#   332. anom_swh_max_deseasonalized_trend_3_lag_1_swan
#   333. anom_swh_max_deseasonalized_trend_3_lag_3_swan
#   334. anom_swh_max_deseasonalized_trend_3_lag_5_swan
#   335. anom_swh_max_deseasonalized_trend_3_lag_7_swan
#   336. anom_swh_max_deseasonalized_trend_3_swan
#   337. anom_swh_max_deseasonalized_trend_5_lag_14_swan
#   338. anom_swh_max_deseasonalized_trend_5_lag_1_swan
#   339. anom_swh_max_deseasonalized_trend_5_lag_3_swan
#   340. anom_swh_max_deseasonalized_trend_5_lag_5_swan
#   341. anom_swh_max_deseasonalized_trend_5_lag_7_swan
#   342. anom_swh_max_deseasonalized_trend_5_swan
#   343. anom_swh_max_deseasonalized_trend_7_lag_14_swan
#   344. anom_swh_max_deseasonalized_trend_7_lag_1_swan
#   345. anom_swh_max_deseasonalized_trend_7_lag_3_swan
#   346. anom_swh_max_deseasonalized_trend_7_lag_5_swan
#   347. anom_swh_max_deseasonalized_trend_7_lag_7_swan
#   348. anom_swh_max_deseasonalized_trend_7_swan
#   349. anom_swh_max_lag_14_swan
#   350. anom_swh_max_lag_1_swan
#   351. anom_swh_max_lag_3_swan
#   352. anom_swh_max_lag_5_swan
#   353. anom_swh_max_lag_7_swan
#   354. anom_swh_max_ma_14_lag_14_swan
#   355. anom_swh_max_ma_14_lag_1_swan
#   356. anom_swh_max_ma_14_lag_3_swan
#   357. anom_swh_max_ma_14_lag_5_swan
#   358. anom_swh_max_ma_14_lag_7_swan
#   359. anom_swh_max_ma_14_swan
#   360. anom_swh_max_ma_2_lag_14_swan
#   361. anom_swh_max_ma_2_lag_1_swan
#   362. anom_swh_max_ma_2_lag_3_swan
#   363. anom_swh_max_ma_2_lag_5_swan
#   364. anom_swh_max_ma_2_lag_7_swan
#   365. anom_swh_max_ma_2_swan
#   366. anom_swh_max_ma_3_lag_14_swan
#   367. anom_swh_max_ma_3_lag_1_swan
#   368. anom_swh_max_ma_3_lag_3_swan
#   369. anom_swh_max_ma_3_lag_5_swan
#   370. anom_swh_max_ma_3_lag_7_swan
#   371. anom_swh_max_ma_3_swan
#   372. anom_swh_max_ma_5_lag_14_swan
#   373. anom_swh_max_ma_5_lag_1_swan
#   374. anom_swh_max_ma_5_lag_3_swan
#   375. anom_swh_max_ma_5_lag_5_swan
#   376. anom_swh_max_ma_5_lag_7_swan
#   377. anom_swh_max_ma_5_swan
#   378. anom_swh_max_ma_7_lag_14_swan
#   379. anom_swh_max_ma_7_lag_1_swan
#   380. anom_swh_max_ma_7_lag_3_swan
#   381. anom_swh_max_ma_7_lag_5_swan
#   382. anom_swh_max_ma_7_lag_7_swan
#   383. anom_swh_max_ma_7_swan
#   384. anom_swh_max_persistence_14_lag_14_swan
#   385. anom_swh_max_persistence_14_lag_1_swan
#   386. anom_swh_max_persistence_14_lag_3_swan
#   387. anom_swh_max_persistence_14_lag_5_swan
#   388. anom_swh_max_persistence_14_lag_7_swan
#   389. anom_swh_max_persistence_14_swan
#   390. anom_swh_max_persistence_2_lag_14_swan
#   391. anom_swh_max_persistence_2_lag_1_swan
#   392. anom_swh_max_persistence_2_lag_3_swan
#   393. anom_swh_max_persistence_2_lag_5_swan
#   394. anom_swh_max_persistence_2_lag_7_swan
#   395. anom_swh_max_persistence_2_swan
#   396. anom_swh_max_persistence_3_lag_14_swan
#   397. anom_swh_max_persistence_3_lag_1_swan
#   398. anom_swh_max_persistence_3_lag_3_swan
#   399. anom_swh_max_persistence_3_lag_5_swan
#   400. anom_swh_max_persistence_3_lag_7_swan
#   401. anom_swh_max_persistence_3_swan
#   402. anom_swh_max_persistence_5_lag_14_swan
#   403. anom_swh_max_persistence_5_lag_1_swan
#   404. anom_swh_max_persistence_5_lag_3_swan
#   405. anom_swh_max_persistence_5_lag_5_swan
#   406. anom_swh_max_persistence_5_lag_7_swan
#   407. anom_swh_max_persistence_5_swan
#   408. anom_swh_max_persistence_7_lag_14_swan
#   409. anom_swh_max_persistence_7_lag_1_swan
#   410. anom_swh_max_persistence_7_lag_3_swan
#   411. anom_swh_max_persistence_7_lag_5_swan
#   412. anom_swh_max_persistence_7_lag_7_swan
#   413. anom_swh_max_persistence_7_swan
#   414. anom_swh_max_rel_change_14_lag_14_swan
#   415. anom_swh_max_rel_change_14_lag_1_swan
#   416. anom_swh_max_rel_change_14_lag_3_swan
#   417. anom_swh_max_rel_change_14_lag_5_swan
#   418. anom_swh_max_rel_change_14_lag_7_swan
#   419. anom_swh_max_rel_change_14_swan
#   420. anom_swh_max_rel_change_3_lag_14_swan
#   421. anom_swh_max_rel_change_3_lag_1_swan
#   422. anom_swh_max_rel_change_3_lag_3_swan
#   423. anom_swh_max_rel_change_3_lag_5_swan
#   424. anom_swh_max_rel_change_3_lag_7_swan
#   425. anom_swh_max_rel_change_3_swan
#   426. anom_swh_max_rel_change_5_lag_14_swan
#   427. anom_swh_max_rel_change_5_lag_1_swan
#   428. anom_swh_max_rel_change_5_lag_3_swan
#   429. anom_swh_max_rel_change_5_lag_5_swan
#   430. anom_swh_max_rel_change_5_lag_7_swan
#   431. anom_swh_max_rel_change_5_swan
#   432. anom_swh_max_rel_change_7_lag_14_swan
#   433. anom_swh_max_rel_change_7_lag_1_swan
#   434. anom_swh_max_rel_change_7_lag_3_swan
#   435. anom_swh_max_rel_change_7_lag_5_swan
#   436. anom_swh_max_rel_change_7_lag_7_swan
#   437. anom_swh_max_rel_change_7_swan
#   438. anom_swh_max_rolling_mean_14_lag_14_swan
#   439. anom_swh_max_rolling_mean_14_lag_1_swan
#   440. anom_swh_max_rolling_mean_14_lag_3_swan
#   441. anom_swh_max_rolling_mean_14_lag_5_swan
#   442. anom_swh_max_rolling_mean_14_lag_7_swan
#   443. anom_swh_max_rolling_mean_14_swan
#   444. anom_swh_max_rolling_mean_3_lag_14_swan
#   445. anom_swh_max_rolling_mean_3_lag_1_swan
#   446. anom_swh_max_rolling_mean_3_lag_3_swan
#   447. anom_swh_max_rolling_mean_3_lag_5_swan
#   448. anom_swh_max_rolling_mean_3_lag_7_swan
#   449. anom_swh_max_rolling_mean_3_swan
#   450. anom_swh_max_rolling_mean_5_lag_14_swan
#   451. anom_swh_max_rolling_mean_5_lag_1_swan
#   452. anom_swh_max_rolling_mean_5_lag_3_swan
#   453. anom_swh_max_rolling_mean_5_lag_5_swan
#   454. anom_swh_max_rolling_mean_5_lag_7_swan
#   455. anom_swh_max_rolling_mean_5_swan
#   456. anom_swh_max_rolling_mean_7_lag_14_swan
#   457. anom_swh_max_rolling_mean_7_lag_1_swan
#   458. anom_swh_max_rolling_mean_7_lag_3_swan
#   459. anom_swh_max_rolling_mean_7_lag_5_swan
#   460. anom_swh_max_rolling_mean_7_lag_7_swan
#   461. anom_swh_max_rolling_mean_7_swan
#   462. anom_swh_max_swan
#   463. anom_swh_max_trend_14_lag_14_swan
#   464. anom_swh_max_trend_14_lag_1_swan
#   465. anom_swh_max_trend_14_lag_3_swan
#   466. anom_swh_max_trend_14_lag_5_swan
#   467. anom_swh_max_trend_14_lag_7_swan
#   468. anom_swh_max_trend_14_swan
#   469. anom_swh_max_trend_3_lag_14_swan
#   470. anom_swh_max_trend_3_lag_1_swan
#   471. anom_swh_max_trend_3_lag_3_swan
#   472. anom_swh_max_trend_3_lag_5_swan
#   473. anom_swh_max_trend_3_lag_7_swan
#   474. anom_swh_max_trend_3_swan
#   475. anom_swh_max_trend_5_lag_14_swan
#   476. anom_swh_max_trend_5_lag_1_swan
#   477. anom_swh_max_trend_5_lag_3_swan
#   478. anom_swh_max_trend_5_lag_5_swan
#   479. anom_swh_max_trend_5_lag_7_swan
#   480. anom_swh_max_trend_5_swan
#   481. anom_swh_max_trend_7_lag_14_swan
#   482. anom_swh_max_trend_7_lag_1_swan
#   483. anom_swh_max_trend_7_lag_3_swan
#   484. anom_swh_max_trend_7_lag_5_swan
#   485. anom_swh_max_trend_7_lag_7_swan
#   486. anom_swh_max_trend_7_swan
#   487. swh_max_abs_change_14_lag_14_swan
#   488. swh_max_abs_change_14_lag_1_swan
#   489. swh_max_abs_change_14_lag_3_swan
#   490. swh_max_abs_change_14_lag_5_swan
#   491. swh_max_abs_change_14_lag_7_swan
#   492. swh_max_abs_change_14_swan
#   493. swh_max_abs_change_3_lag_14_swan
#   494. swh_max_abs_change_3_lag_1_swan
#   495. swh_max_abs_change_3_lag_3_swan
#   496. swh_max_abs_change_3_lag_5_swan
#   497. swh_max_abs_change_3_lag_7_swan
#   498. swh_max_abs_change_3_swan
#   499. swh_max_abs_change_5_lag_14_swan
#   500. swh_max_abs_change_5_lag_1_swan
#   501. swh_max_abs_change_5_lag_3_swan
#   502. swh_max_abs_change_5_lag_5_swan
#   503. swh_max_abs_change_5_lag_7_swan
#   504. swh_max_abs_change_5_swan
#   505. swh_max_abs_change_7_lag_14_swan
#   506. swh_max_abs_change_7_lag_1_swan
#   507. swh_max_abs_change_7_lag_3_swan
#   508. swh_max_abs_change_7_lag_5_swan
#   509. swh_max_abs_change_7_lag_7_swan
#   510. swh_max_abs_change_7_swan
#   511. swh_max_deseasonalized_abs_change_14_lag_14_swan
#   512. swh_max_deseasonalized_abs_change_14_lag_1_swan
#   513. swh_max_deseasonalized_abs_change_14_lag_3_swan
#   514. swh_max_deseasonalized_abs_change_14_lag_5_swan
#   515. swh_max_deseasonalized_abs_change_14_lag_7_swan
#   516. swh_max_deseasonalized_abs_change_14_swan
#   517. swh_max_deseasonalized_abs_change_3_lag_14_swan
#   518. swh_max_deseasonalized_abs_change_3_lag_1_swan
#   519. swh_max_deseasonalized_abs_change_3_lag_3_swan
#   520. swh_max_deseasonalized_abs_change_3_lag_5_swan
#   521. swh_max_deseasonalized_abs_change_3_lag_7_swan
#   522. swh_max_deseasonalized_abs_change_3_swan
#   523. swh_max_deseasonalized_abs_change_5_lag_14_swan
#   524. swh_max_deseasonalized_abs_change_5_lag_1_swan
#   525. swh_max_deseasonalized_abs_change_5_lag_3_swan
#   526. swh_max_deseasonalized_abs_change_5_lag_5_swan
#   527. swh_max_deseasonalized_abs_change_5_lag_7_swan
#   528. swh_max_deseasonalized_abs_change_5_swan
#   529. swh_max_deseasonalized_abs_change_7_lag_14_swan
#   530. swh_max_deseasonalized_abs_change_7_lag_1_swan
#   531. swh_max_deseasonalized_abs_change_7_lag_3_swan
#   532. swh_max_deseasonalized_abs_change_7_lag_5_swan
#   533. swh_max_deseasonalized_abs_change_7_lag_7_swan
#   534. swh_max_deseasonalized_abs_change_7_swan
#   535. swh_max_deseasonalized_detrended_abs_change_14_lag_14_swan
#   536. swh_max_deseasonalized_detrended_abs_change_14_lag_1_swan
#   537. swh_max_deseasonalized_detrended_abs_change_14_lag_3_swan
#   538. swh_max_deseasonalized_detrended_abs_change_14_lag_5_swan
#   539. swh_max_deseasonalized_detrended_abs_change_14_lag_7_swan
#   540. swh_max_deseasonalized_detrended_abs_change_14_swan
#   541. swh_max_deseasonalized_detrended_abs_change_3_lag_14_swan
#   542. swh_max_deseasonalized_detrended_abs_change_3_lag_1_swan
#   543. swh_max_deseasonalized_detrended_abs_change_3_lag_3_swan
#   544. swh_max_deseasonalized_detrended_abs_change_3_lag_5_swan
#   545. swh_max_deseasonalized_detrended_abs_change_3_lag_7_swan
#   546. swh_max_deseasonalized_detrended_abs_change_3_swan
#   547. swh_max_deseasonalized_detrended_abs_change_5_lag_14_swan
#   548. swh_max_deseasonalized_detrended_abs_change_5_lag_1_swan
#   549. swh_max_deseasonalized_detrended_abs_change_5_lag_3_swan
#   550. swh_max_deseasonalized_detrended_abs_change_5_lag_5_swan
#   551. swh_max_deseasonalized_detrended_abs_change_5_lag_7_swan
#   552. swh_max_deseasonalized_detrended_abs_change_5_swan
#   553. swh_max_deseasonalized_detrended_abs_change_7_lag_14_swan
#   554. swh_max_deseasonalized_detrended_abs_change_7_lag_1_swan
#   555. swh_max_deseasonalized_detrended_abs_change_7_lag_3_swan
#   556. swh_max_deseasonalized_detrended_abs_change_7_lag_5_swan
#   557. swh_max_deseasonalized_detrended_abs_change_7_lag_7_swan
#   558. swh_max_deseasonalized_detrended_abs_change_7_swan
#   559. swh_max_deseasonalized_detrended_lag_14_swan
#   560. swh_max_deseasonalized_detrended_lag_1_swan
#   561. swh_max_deseasonalized_detrended_lag_3_swan
#   562. swh_max_deseasonalized_detrended_lag_5_swan
#   563. swh_max_deseasonalized_detrended_lag_7_swan
#   564. swh_max_deseasonalized_detrended_ma_14_lag_14_swan
#   565. swh_max_deseasonalized_detrended_ma_14_lag_1_swan
#   566. swh_max_deseasonalized_detrended_ma_14_lag_3_swan
#   567. swh_max_deseasonalized_detrended_ma_14_lag_5_swan
#   568. swh_max_deseasonalized_detrended_ma_14_lag_7_swan
#   569. swh_max_deseasonalized_detrended_ma_14_swan
#   570. swh_max_deseasonalized_detrended_ma_2_lag_14_swan
#   571. swh_max_deseasonalized_detrended_ma_2_lag_1_swan
#   572. swh_max_deseasonalized_detrended_ma_2_lag_3_swan
#   573. swh_max_deseasonalized_detrended_ma_2_lag_5_swan
#   574. swh_max_deseasonalized_detrended_ma_2_lag_7_swan
#   575. swh_max_deseasonalized_detrended_ma_2_swan
#   576. swh_max_deseasonalized_detrended_ma_3_lag_14_swan
#   577. swh_max_deseasonalized_detrended_ma_3_lag_1_swan
#   578. swh_max_deseasonalized_detrended_ma_3_lag_3_swan
#   579. swh_max_deseasonalized_detrended_ma_3_lag_5_swan
#   580. swh_max_deseasonalized_detrended_ma_3_lag_7_swan
#   581. swh_max_deseasonalized_detrended_ma_3_swan
#   582. swh_max_deseasonalized_detrended_ma_5_lag_14_swan
#   583. swh_max_deseasonalized_detrended_ma_5_lag_1_swan
#   584. swh_max_deseasonalized_detrended_ma_5_lag_3_swan
#   585. swh_max_deseasonalized_detrended_ma_5_lag_5_swan
#   586. swh_max_deseasonalized_detrended_ma_5_lag_7_swan
#   587. swh_max_deseasonalized_detrended_ma_5_swan
#   588. swh_max_deseasonalized_detrended_ma_7_lag_14_swan
#   589. swh_max_deseasonalized_detrended_ma_7_lag_1_swan
#   590. swh_max_deseasonalized_detrended_ma_7_lag_3_swan
#   591. swh_max_deseasonalized_detrended_ma_7_lag_5_swan
#   592. swh_max_deseasonalized_detrended_ma_7_lag_7_swan
#   593. swh_max_deseasonalized_detrended_ma_7_swan
#   594. swh_max_deseasonalized_detrended_persistence_14_lag_14_swan
#   595. swh_max_deseasonalized_detrended_persistence_14_lag_1_swan
#   596. swh_max_deseasonalized_detrended_persistence_14_lag_3_swan
#   597. swh_max_deseasonalized_detrended_persistence_14_lag_5_swan
#   598. swh_max_deseasonalized_detrended_persistence_14_lag_7_swan
#   599. swh_max_deseasonalized_detrended_persistence_14_swan
#   600. swh_max_deseasonalized_detrended_persistence_2_lag_14_swan
#   601. swh_max_deseasonalized_detrended_persistence_2_lag_1_swan
#   602. swh_max_deseasonalized_detrended_persistence_2_lag_3_swan
#   603. swh_max_deseasonalized_detrended_persistence_2_lag_5_swan
#   604. swh_max_deseasonalized_detrended_persistence_2_lag_7_swan
#   605. swh_max_deseasonalized_detrended_persistence_2_swan
#   606. swh_max_deseasonalized_detrended_persistence_3_lag_14_swan
#   607. swh_max_deseasonalized_detrended_persistence_3_lag_1_swan
#   608. swh_max_deseasonalized_detrended_persistence_3_lag_3_swan
#   609. swh_max_deseasonalized_detrended_persistence_3_lag_5_swan
#   610. swh_max_deseasonalized_detrended_persistence_3_lag_7_swan
#   611. swh_max_deseasonalized_detrended_persistence_3_swan
#   612. swh_max_deseasonalized_detrended_persistence_5_lag_14_swan
#   613. swh_max_deseasonalized_detrended_persistence_5_lag_1_swan
#   614. swh_max_deseasonalized_detrended_persistence_5_lag_3_swan
#   615. swh_max_deseasonalized_detrended_persistence_5_lag_5_swan
#   616. swh_max_deseasonalized_detrended_persistence_5_lag_7_swan
#   617. swh_max_deseasonalized_detrended_persistence_5_swan
#   618. swh_max_deseasonalized_detrended_persistence_7_lag_14_swan
#   619. swh_max_deseasonalized_detrended_persistence_7_lag_1_swan
#   620. swh_max_deseasonalized_detrended_persistence_7_lag_3_swan
#   621. swh_max_deseasonalized_detrended_persistence_7_lag_5_swan
#   622. swh_max_deseasonalized_detrended_persistence_7_lag_7_swan
#   623. swh_max_deseasonalized_detrended_persistence_7_swan
#   624. swh_max_deseasonalized_detrended_rel_change_14_lag_14_swan
#   625. swh_max_deseasonalized_detrended_rel_change_14_lag_1_swan
#   626. swh_max_deseasonalized_detrended_rel_change_14_lag_3_swan
#   627. swh_max_deseasonalized_detrended_rel_change_14_lag_5_swan
#   628. swh_max_deseasonalized_detrended_rel_change_14_lag_7_swan
#   629. swh_max_deseasonalized_detrended_rel_change_14_swan
#   630. swh_max_deseasonalized_detrended_rel_change_3_lag_14_swan
#   631. swh_max_deseasonalized_detrended_rel_change_3_lag_1_swan
#   632. swh_max_deseasonalized_detrended_rel_change_3_lag_3_swan
#   633. swh_max_deseasonalized_detrended_rel_change_3_lag_5_swan
#   634. swh_max_deseasonalized_detrended_rel_change_3_lag_7_swan
#   635. swh_max_deseasonalized_detrended_rel_change_3_swan
#   636. swh_max_deseasonalized_detrended_rel_change_5_lag_14_swan
#   637. swh_max_deseasonalized_detrended_rel_change_5_lag_1_swan
#   638. swh_max_deseasonalized_detrended_rel_change_5_lag_3_swan
#   639. swh_max_deseasonalized_detrended_rel_change_5_lag_5_swan
#   640. swh_max_deseasonalized_detrended_rel_change_5_lag_7_swan
#   641. swh_max_deseasonalized_detrended_rel_change_5_swan
#   642. swh_max_deseasonalized_detrended_rel_change_7_lag_14_swan
#   643. swh_max_deseasonalized_detrended_rel_change_7_lag_1_swan
#   644. swh_max_deseasonalized_detrended_rel_change_7_lag_3_swan
#   645. swh_max_deseasonalized_detrended_rel_change_7_lag_5_swan
#   646. swh_max_deseasonalized_detrended_rel_change_7_lag_7_swan
#   647. swh_max_deseasonalized_detrended_rel_change_7_swan
#   648. swh_max_deseasonalized_detrended_rolling_mean_14_lag_14_swan
#   649. swh_max_deseasonalized_detrended_rolling_mean_14_lag_1_swan
#   650. swh_max_deseasonalized_detrended_rolling_mean_14_lag_3_swan
#   651. swh_max_deseasonalized_detrended_rolling_mean_14_lag_5_swan
#   652. swh_max_deseasonalized_detrended_rolling_mean_14_lag_7_swan
#   653. swh_max_deseasonalized_detrended_rolling_mean_14_swan
#   654. swh_max_deseasonalized_detrended_rolling_mean_3_lag_14_swan
#   655. swh_max_deseasonalized_detrended_rolling_mean_3_lag_1_swan
#   656. swh_max_deseasonalized_detrended_rolling_mean_3_lag_3_swan
#   657. swh_max_deseasonalized_detrended_rolling_mean_3_lag_5_swan
#   658. swh_max_deseasonalized_detrended_rolling_mean_3_lag_7_swan
#   659. swh_max_deseasonalized_detrended_rolling_mean_3_swan
#   660. swh_max_deseasonalized_detrended_rolling_mean_5_lag_14_swan
#   661. swh_max_deseasonalized_detrended_rolling_mean_5_lag_1_swan
#   662. swh_max_deseasonalized_detrended_rolling_mean_5_lag_3_swan
#   663. swh_max_deseasonalized_detrended_rolling_mean_5_lag_5_swan
#   664. swh_max_deseasonalized_detrended_rolling_mean_5_lag_7_swan
#   665. swh_max_deseasonalized_detrended_rolling_mean_5_swan
#   666. swh_max_deseasonalized_detrended_rolling_mean_7_lag_14_swan
#   667. swh_max_deseasonalized_detrended_rolling_mean_7_lag_1_swan
#   668. swh_max_deseasonalized_detrended_rolling_mean_7_lag_3_swan
#   669. swh_max_deseasonalized_detrended_rolling_mean_7_lag_5_swan
#   670. swh_max_deseasonalized_detrended_rolling_mean_7_lag_7_swan
#   671. swh_max_deseasonalized_detrended_rolling_mean_7_swan
#   672. swh_max_deseasonalized_detrended_swan
#   673. swh_max_deseasonalized_detrended_trend_14_lag_14_swan
#   674. swh_max_deseasonalized_detrended_trend_14_lag_1_swan
#   675. swh_max_deseasonalized_detrended_trend_14_lag_3_swan
#   676. swh_max_deseasonalized_detrended_trend_14_lag_5_swan
#   677. swh_max_deseasonalized_detrended_trend_14_lag_7_swan
#   678. swh_max_deseasonalized_detrended_trend_14_swan
#   679. swh_max_deseasonalized_detrended_trend_3_lag_14_swan
#   680. swh_max_deseasonalized_detrended_trend_3_lag_1_swan
#   681. swh_max_deseasonalized_detrended_trend_3_lag_3_swan
#   682. swh_max_deseasonalized_detrended_trend_3_lag_5_swan
#   683. swh_max_deseasonalized_detrended_trend_3_lag_7_swan
#   684. swh_max_deseasonalized_detrended_trend_3_swan
#   685. swh_max_deseasonalized_detrended_trend_5_lag_14_swan
#   686. swh_max_deseasonalized_detrended_trend_5_lag_1_swan
#   687. swh_max_deseasonalized_detrended_trend_5_lag_3_swan
#   688. swh_max_deseasonalized_detrended_trend_5_lag_5_swan
#   689. swh_max_deseasonalized_detrended_trend_5_lag_7_swan
#   690. swh_max_deseasonalized_detrended_trend_5_swan
#   691. swh_max_deseasonalized_detrended_trend_7_lag_14_swan
#   692. swh_max_deseasonalized_detrended_trend_7_lag_1_swan
#   693. swh_max_deseasonalized_detrended_trend_7_lag_3_swan
#   694. swh_max_deseasonalized_detrended_trend_7_lag_5_swan
#   695. swh_max_deseasonalized_detrended_trend_7_lag_7_swan
#   696. swh_max_deseasonalized_detrended_trend_7_swan
#   697. swh_max_deseasonalized_lag_14_swan
#   698. swh_max_deseasonalized_lag_1_swan
#   699. swh_max_deseasonalized_lag_3_swan
#   700. swh_max_deseasonalized_lag_5_swan
#   701. swh_max_deseasonalized_lag_7_swan
#   702. swh_max_deseasonalized_ma_14_lag_14_swan
#   703. swh_max_deseasonalized_ma_14_lag_1_swan
#   704. swh_max_deseasonalized_ma_14_lag_3_swan
#   705. swh_max_deseasonalized_ma_14_lag_5_swan
#   706. swh_max_deseasonalized_ma_14_lag_7_swan
#   707. swh_max_deseasonalized_ma_14_swan
#   708. swh_max_deseasonalized_ma_2_lag_14_swan
#   709. swh_max_deseasonalized_ma_2_lag_1_swan
#   710. swh_max_deseasonalized_ma_2_lag_3_swan
#   711. swh_max_deseasonalized_ma_2_lag_5_swan
#   712. swh_max_deseasonalized_ma_2_lag_7_swan
#   713. swh_max_deseasonalized_ma_2_swan
#   714. swh_max_deseasonalized_ma_3_lag_14_swan
#   715. swh_max_deseasonalized_ma_3_lag_1_swan
#   716. swh_max_deseasonalized_ma_3_lag_3_swan
#   717. swh_max_deseasonalized_ma_3_lag_5_swan
#   718. swh_max_deseasonalized_ma_3_lag_7_swan
#   719. swh_max_deseasonalized_ma_3_swan
#   720. swh_max_deseasonalized_ma_5_lag_14_swan
#   721. swh_max_deseasonalized_ma_5_lag_1_swan
#   722. swh_max_deseasonalized_ma_5_lag_3_swan
#   723. swh_max_deseasonalized_ma_5_lag_5_swan
#   724. swh_max_deseasonalized_ma_5_lag_7_swan
#   725. swh_max_deseasonalized_ma_5_swan
#   726. swh_max_deseasonalized_ma_7_lag_14_swan
#   727. swh_max_deseasonalized_ma_7_lag_1_swan
#   728. swh_max_deseasonalized_ma_7_lag_3_swan
#   729. swh_max_deseasonalized_ma_7_lag_5_swan
#   730. swh_max_deseasonalized_ma_7_lag_7_swan
#   731. swh_max_deseasonalized_ma_7_swan
#   732. swh_max_deseasonalized_persistence_14_lag_14_swan
#   733. swh_max_deseasonalized_persistence_14_lag_1_swan
#   734. swh_max_deseasonalized_persistence_14_lag_3_swan
#   735. swh_max_deseasonalized_persistence_14_lag_5_swan
#   736. swh_max_deseasonalized_persistence_14_lag_7_swan
#   737. swh_max_deseasonalized_persistence_14_swan
#   738. swh_max_deseasonalized_persistence_2_lag_14_swan
#   739. swh_max_deseasonalized_persistence_2_lag_1_swan
#   740. swh_max_deseasonalized_persistence_2_lag_3_swan
#   741. swh_max_deseasonalized_persistence_2_lag_5_swan
#   742. swh_max_deseasonalized_persistence_2_lag_7_swan
#   743. swh_max_deseasonalized_persistence_2_swan
#   744. swh_max_deseasonalized_persistence_3_lag_14_swan
#   745. swh_max_deseasonalized_persistence_3_lag_1_swan
#   746. swh_max_deseasonalized_persistence_3_lag_3_swan
#   747. swh_max_deseasonalized_persistence_3_lag_5_swan
#   748. swh_max_deseasonalized_persistence_3_lag_7_swan
#   749. swh_max_deseasonalized_persistence_3_swan
#   750. swh_max_deseasonalized_persistence_5_lag_14_swan
#   751. swh_max_deseasonalized_persistence_5_lag_1_swan
#   752. swh_max_deseasonalized_persistence_5_lag_3_swan
#   753. swh_max_deseasonalized_persistence_5_lag_5_swan
#   754. swh_max_deseasonalized_persistence_5_lag_7_swan
#   755. swh_max_deseasonalized_persistence_5_swan
#   756. swh_max_deseasonalized_persistence_7_lag_14_swan
#   757. swh_max_deseasonalized_persistence_7_lag_1_swan
#   758. swh_max_deseasonalized_persistence_7_lag_3_swan
#   759. swh_max_deseasonalized_persistence_7_lag_5_swan
#   760. swh_max_deseasonalized_persistence_7_lag_7_swan
#   761. swh_max_deseasonalized_persistence_7_swan
#   762. swh_max_deseasonalized_rel_change_14_lag_14_swan
#   763. swh_max_deseasonalized_rel_change_14_lag_1_swan
#   764. swh_max_deseasonalized_rel_change_14_lag_3_swan
#   765. swh_max_deseasonalized_rel_change_14_lag_5_swan
#   766. swh_max_deseasonalized_rel_change_14_lag_7_swan
#   767. swh_max_deseasonalized_rel_change_14_swan
#   768. swh_max_deseasonalized_rel_change_3_lag_14_swan
#   769. swh_max_deseasonalized_rel_change_3_lag_1_swan
#   770. swh_max_deseasonalized_rel_change_3_lag_3_swan
#   771. swh_max_deseasonalized_rel_change_3_lag_5_swan
#   772. swh_max_deseasonalized_rel_change_3_lag_7_swan
#   773. swh_max_deseasonalized_rel_change_3_swan
#   774. swh_max_deseasonalized_rel_change_5_lag_14_swan
#   775. swh_max_deseasonalized_rel_change_5_lag_1_swan
#   776. swh_max_deseasonalized_rel_change_5_lag_3_swan
#   777. swh_max_deseasonalized_rel_change_5_lag_5_swan
#   778. swh_max_deseasonalized_rel_change_5_lag_7_swan
#   779. swh_max_deseasonalized_rel_change_5_swan
#   780. swh_max_deseasonalized_rel_change_7_lag_14_swan
#   781. swh_max_deseasonalized_rel_change_7_lag_1_swan
#   782. swh_max_deseasonalized_rel_change_7_lag_3_swan
#   783. swh_max_deseasonalized_rel_change_7_lag_5_swan
#   784. swh_max_deseasonalized_rel_change_7_lag_7_swan
#   785. swh_max_deseasonalized_rel_change_7_swan
#   786. swh_max_deseasonalized_rolling_mean_14_lag_14_swan
#   787. swh_max_deseasonalized_rolling_mean_14_lag_1_swan
#   788. swh_max_deseasonalized_rolling_mean_14_lag_3_swan
#   789. swh_max_deseasonalized_rolling_mean_14_lag_5_swan
#   790. swh_max_deseasonalized_rolling_mean_14_lag_7_swan
#   791. swh_max_deseasonalized_rolling_mean_14_swan
#   792. swh_max_deseasonalized_rolling_mean_3_lag_14_swan
#   793. swh_max_deseasonalized_rolling_mean_3_lag_1_swan
#   794. swh_max_deseasonalized_rolling_mean_3_lag_3_swan
#   795. swh_max_deseasonalized_rolling_mean_3_lag_5_swan
#   796. swh_max_deseasonalized_rolling_mean_3_lag_7_swan
#   797. swh_max_deseasonalized_rolling_mean_3_swan
#   798. swh_max_deseasonalized_rolling_mean_5_lag_14_swan
#   799. swh_max_deseasonalized_rolling_mean_5_lag_1_swan
#   800. swh_max_deseasonalized_rolling_mean_5_lag_3_swan
#   801. swh_max_deseasonalized_rolling_mean_5_lag_5_swan
#   802. swh_max_deseasonalized_rolling_mean_5_lag_7_swan
#   803. swh_max_deseasonalized_rolling_mean_5_swan
#   804. swh_max_deseasonalized_rolling_mean_7_lag_14_swan
#   805. swh_max_deseasonalized_rolling_mean_7_lag_1_swan
#   806. swh_max_deseasonalized_rolling_mean_7_lag_3_swan
#   807. swh_max_deseasonalized_rolling_mean_7_lag_5_swan
#   808. swh_max_deseasonalized_rolling_mean_7_lag_7_swan
#   809. swh_max_deseasonalized_rolling_mean_7_swan
#   810. swh_max_deseasonalized_swan
#   811. swh_max_deseasonalized_trend_14_lag_14_swan
#   812. swh_max_deseasonalized_trend_14_lag_1_swan
#   813. swh_max_deseasonalized_trend_14_lag_3_swan
#   814. swh_max_deseasonalized_trend_14_lag_5_swan
#   815. swh_max_deseasonalized_trend_14_lag_7_swan
#   816. swh_max_deseasonalized_trend_14_swan
#   817. swh_max_deseasonalized_trend_3_lag_14_swan
#   818. swh_max_deseasonalized_trend_3_lag_1_swan
#   819. swh_max_deseasonalized_trend_3_lag_3_swan
#   820. swh_max_deseasonalized_trend_3_lag_5_swan
#   821. swh_max_deseasonalized_trend_3_lag_7_swan
#   822. swh_max_deseasonalized_trend_3_swan
#   823. swh_max_deseasonalized_trend_5_lag_14_swan
#   824. swh_max_deseasonalized_trend_5_lag_1_swan
#   825. swh_max_deseasonalized_trend_5_lag_3_swan
#   826. swh_max_deseasonalized_trend_5_lag_5_swan
#   827. swh_max_deseasonalized_trend_5_lag_7_swan
#   828. swh_max_deseasonalized_trend_5_swan
#   829. swh_max_deseasonalized_trend_7_lag_14_swan
#   830. swh_max_deseasonalized_trend_7_lag_1_swan
#   831. swh_max_deseasonalized_trend_7_lag_3_swan
#   832. swh_max_deseasonalized_trend_7_lag_5_swan
#   833. swh_max_deseasonalized_trend_7_lag_7_swan
#   834. swh_max_deseasonalized_trend_7_swan
#   835. swh_max_lag_14_swan
#   836. swh_max_lag_1_swan
#   837. swh_max_lag_3_swan
#   838. swh_max_lag_5_swan
#   839. swh_max_lag_7_swan
#   840. swh_max_ma_14_lag_14_swan
#   841. swh_max_ma_14_lag_1_swan
#   842. swh_max_ma_14_lag_3_swan
#   843. swh_max_ma_14_lag_5_swan
#   844. swh_max_ma_14_lag_7_swan
#   845. swh_max_ma_14_swan
#   846. swh_max_ma_2_lag_14_swan
#   847. swh_max_ma_2_lag_1_swan
#   848. swh_max_ma_2_lag_3_swan
#   849. swh_max_ma_2_lag_5_swan
#   850. swh_max_ma_2_lag_7_swan
#   851. swh_max_ma_2_swan
#   852. swh_max_ma_3_lag_14_swan
#   853. swh_max_ma_3_lag_1_swan
#   854. swh_max_ma_3_lag_3_swan
#   855. swh_max_ma_3_lag_5_swan
#   856. swh_max_ma_3_lag_7_swan
#   857. swh_max_ma_3_swan
#   858. swh_max_ma_5_lag_14_swan
#   859. swh_max_ma_5_lag_1_swan
#   860. swh_max_ma_5_lag_3_swan
#   861. swh_max_ma_5_lag_5_swan
#   862. swh_max_ma_5_lag_7_swan
#   863. swh_max_ma_5_swan
#   864. swh_max_ma_7_lag_14_swan
#   865. swh_max_ma_7_lag_1_swan
#   866. swh_max_ma_7_lag_3_swan
#   867. swh_max_ma_7_lag_5_swan
#   868. swh_max_ma_7_lag_7_swan
#   869. swh_max_ma_7_swan
#   870. swh_max_persistence_14_lag_14_swan
#   871. swh_max_persistence_14_lag_1_swan
#   872. swh_max_persistence_14_lag_3_swan
#   873. swh_max_persistence_14_lag_5_swan
#   874. swh_max_persistence_14_lag_7_swan
#   875. swh_max_persistence_14_swan
#   876. swh_max_persistence_2_lag_14_swan
#   877. swh_max_persistence_2_lag_1_swan
#   878. swh_max_persistence_2_lag_3_swan
#   879. swh_max_persistence_2_lag_5_swan
#   880. swh_max_persistence_2_lag_7_swan
#   881. swh_max_persistence_2_swan
#   882. swh_max_persistence_3_lag_14_swan
#   883. swh_max_persistence_3_lag_1_swan
#   884. swh_max_persistence_3_lag_3_swan
#   885. swh_max_persistence_3_lag_5_swan
#   886. swh_max_persistence_3_lag_7_swan
#   887. swh_max_persistence_3_swan
#   888. swh_max_persistence_5_lag_14_swan
# ...
#   695. swh_max_deseasonalized_detrended_trend_7_lag_7_swan
#   696. swh_max_deseasonalized_detrended_trend_7_swan
#   697. swh_max_deseasonalized_lag_14_swan
#   698. swh_max_deseasonalized_lag_1_swan
#   699. swh_max_deseasonalized_lag_3_swan
#   700. swh_max_deseasonalized_lag_5_swan
#   701. swh_max_deseasonalized_lag_7_swan
#   702. swh_max_deseasonalized_ma_14_lag_14_swan
#   703. swh_max_deseasonalized_ma_14_lag_1_swan
#   704. swh_max_deseasonalized_ma_14_lag_3_swan
#   705. swh_max_deseasonalized_ma_14_lag_5_swan
#   706. swh_max_deseasonalized_ma_14_lag_7_swan
#   707. swh_max_deseasonalized_ma_14_swan
#   708. swh_max_deseasonalized_ma_2_lag_14_swan
#   709. swh_max_deseasonalized_ma_2_lag_1_swan
#   710. swh_max_deseasonalized_ma_2_lag_3_swan
#   711. swh_max_deseasonalized_ma_2_lag_5_swan
#   712. swh_max_deseasonalized_ma_2_lag_7_swan
#   713. swh_max_deseasonalized_ma_2_swan
#   714. swh_max_deseasonalized_ma_3_lag_14_swan
#   715. swh_max_deseasonalized_ma_3_lag_1_swan
#   716. swh_max_deseasonalized_ma_3_lag_3_swan
#   717. swh_max_deseasonalized_ma_3_lag_5_swan
#   718. swh_max_deseasonalized_ma_3_lag_7_swan
#   719. swh_max_deseasonalized_ma_3_swan
#   720. swh_max_deseasonalized_ma_5_lag_14_swan
#   721. swh_max_deseasonalized_ma_5_lag_1_swan
#   722. swh_max_deseasonalized_ma_5_lag_3_swan
#   723. swh_max_deseasonalized_ma_5_lag_5_swan
#   724. swh_max_deseasonalized_ma_5_lag_7_swan
#   725. swh_max_deseasonalized_ma_5_swan
#   726. swh_max_deseasonalized_ma_7_lag_14_swan
#   727. swh_max_deseasonalized_ma_7_lag_1_swan
#   728. swh_max_deseasonalized_ma_7_lag_3_swan
#   729. swh_max_deseasonalized_ma_7_lag_5_swan
#   730. swh_max_deseasonalized_ma_7_lag_7_swan
#   731. swh_max_deseasonalized_ma_7_swan
#   732. swh_max_deseasonalized_persistence_14_lag_14_swan
#   733. swh_max_deseasonalized_persistence_14_lag_1_swan
#   734. swh_max_deseasonalized_persistence_14_lag_3_swan
#   735. swh_max_deseasonalized_persistence_14_lag_5_swan
#   736. swh_max_deseasonalized_persistence_14_lag_7_swan
#   737. swh_max_deseasonalized_persistence_14_swan
#   738. swh_max_deseasonalized_persistence_2_lag_14_swan
#   739. swh_max_deseasonalized_persistence_2_lag_1_swan
#   740. swh_max_deseasonalized_persistence_2_lag_3_swan
#   741. swh_max_deseasonalized_persistence_2_lag_5_swan
#   742. swh_max_deseasonalized_persistence_2_lag_7_swan
#   743. swh_max_deseasonalized_persistence_2_swan
#   744. swh_max_deseasonalized_persistence_3_lag_14_swan
#   745. swh_max_deseasonalized_persistence_3_lag_1_swan
#   746. swh_max_deseasonalized_persistence_3_lag_3_swan
#   747. swh_max_deseasonalized_persistence_3_lag_5_swan
#   748. swh_max_deseasonalized_persistence_3_lag_7_swan
#   749. swh_max_deseasonalized_persistence_3_swan
#   750. swh_max_deseasonalized_persistence_5_lag_14_swan
#   751. swh_max_deseasonalized_persistence_5_lag_1_swan
#   752. swh_max_deseasonalized_persistence_5_lag_3_swan
#   753. swh_max_deseasonalized_persistence_5_lag_5_swan
#   754. swh_max_deseasonalized_persistence_5_lag_7_swan
#   755. swh_max_deseasonalized_persistence_5_swan
#   756. swh_max_deseasonalized_persistence_7_lag_14_swan
#   757. swh_max_deseasonalized_persistence_7_lag_1_swan
#   758. swh_max_deseasonalized_persistence_7_lag_3_swan
#   759. swh_max_deseasonalized_persistence_7_lag_5_swan
#   760. swh_max_deseasonalized_persistence_7_lag_7_swan
#   761. swh_max_deseasonalized_persistence_7_swan
#   762. swh_max_deseasonalized_rel_change_14_lag_14_swan
#   763. swh_max_deseasonalized_rel_change_14_lag_1_swan
#   764. swh_max_deseasonalized_rel_change_14_lag_3_swan
#   765. swh_max_deseasonalized_rel_change_14_lag_5_swan
#   766. swh_max_deseasonalized_rel_change_14_lag_7_swan
#   767. swh_max_deseasonalized_rel_change_14_swan
#   768. swh_max_deseasonalized_rel_change_3_lag_14_swan
#   769. swh_max_deseasonalized_rel_change_3_lag_1_swan
#   770. swh_max_deseasonalized_rel_change_3_lag_3_swan
#   771. swh_max_deseasonalized_rel_change_3_lag_5_swan
#   772. swh_max_deseasonalized_rel_change_3_lag_7_swan
#   773. swh_max_deseasonalized_rel_change_3_swan
#   774. swh_max_deseasonalized_rel_change_5_lag_14_swan
#   775. swh_max_deseasonalized_rel_change_5_lag_1_swan
#   776. swh_max_deseasonalized_rel_change_5_lag_3_swan
#   777. swh_max_deseasonalized_rel_change_5_lag_5_swan
#   778. swh_max_deseasonalized_rel_change_5_lag_7_swan
#   779. swh_max_deseasonalized_rel_change_5_swan
#   780. swh_max_deseasonalized_rel_change_7_lag_14_swan
#   781. swh_max_deseasonalized_rel_change_7_lag_1_swan
#   782. swh_max_deseasonalized_rel_change_7_lag_3_swan
#   783. swh_max_deseasonalized_rel_change_7_lag_5_swan
#   784. swh_max_deseasonalized_rel_change_7_lag_7_swan
#   785. swh_max_deseasonalized_rel_change_7_swan
#   786. swh_max_deseasonalized_rolling_mean_14_lag_14_swan
#   787. swh_max_deseasonalized_rolling_mean_14_lag_1_swan
#   788. swh_max_deseasonalized_rolling_mean_14_lag_3_swan
#   789. swh_max_deseasonalized_rolling_mean_14_lag_5_swan
#   790. swh_max_deseasonalized_rolling_mean_14_lag_7_swan
#   791. swh_max_deseasonalized_rolling_mean_14_swan
#   792. swh_max_deseasonalized_rolling_mean_3_lag_14_swan
#   793. swh_max_deseasonalized_rolling_mean_3_lag_1_swan
#   794. swh_max_deseasonalized_rolling_mean_3_lag_3_swan
#   795. swh_max_deseasonalized_rolling_mean_3_lag_5_swan
#   796. swh_max_deseasonalized_rolling_mean_3_lag_7_swan
#   797. swh_max_deseasonalized_rolling_mean_3_swan
#   798. swh_max_deseasonalized_rolling_mean_5_lag_14_swan
#   799. swh_max_deseasonalized_rolling_mean_5_lag_1_swan
#   800. swh_max_deseasonalized_rolling_mean_5_lag_3_swan
#   801. swh_max_deseasonalized_rolling_mean_5_lag_5_swan
#   802. swh_max_deseasonalized_rolling_mean_5_lag_7_swan
#   803. swh_max_deseasonalized_rolling_mean_5_swan
#   804. swh_max_deseasonalized_rolling_mean_7_lag_14_swan
#   805. swh_max_deseasonalized_rolling_mean_7_lag_1_swan
#   806. swh_max_deseasonalized_rolling_mean_7_lag_3_swan
#   807. swh_max_deseasonalized_rolling_mean_7_lag_5_swan
#   808. swh_max_deseasonalized_rolling_mean_7_lag_7_swan
#   809. swh_max_deseasonalized_rolling_mean_7_swan
#   810. swh_max_deseasonalized_swan
#   811. swh_max_deseasonalized_trend_14_lag_14_swan
#   812. swh_max_deseasonalized_trend_14_lag_1_swan
#   813. swh_max_deseasonalized_trend_14_lag_3_swan
#   814. swh_max_deseasonalized_trend_14_lag_5_swan
#   815. swh_max_deseasonalized_trend_14_lag_7_swan
#   816. swh_max_deseasonalized_trend_14_swan
#   817. swh_max_deseasonalized_trend_3_lag_14_swan
#   818. swh_max_deseasonalized_trend_3_lag_1_swan
#   819. swh_max_deseasonalized_trend_3_lag_3_swan
#   820. swh_max_deseasonalized_trend_3_lag_5_swan
#   821. swh_max_deseasonalized_trend_3_lag_7_swan
#   822. swh_max_deseasonalized_trend_3_swan
#   823. swh_max_deseasonalized_trend_5_lag_14_swan
#   824. swh_max_deseasonalized_trend_5_lag_1_swan
#   825. swh_max_deseasonalized_trend_5_lag_3_swan
#   826. swh_max_deseasonalized_trend_5_lag_5_swan
#   827. swh_max_deseasonalized_trend_5_lag_7_swan
#   828. swh_max_deseasonalized_trend_5_swan
#   829. swh_max_deseasonalized_trend_7_lag_14_swan
#   830. swh_max_deseasonalized_trend_7_lag_1_swan
#   831. swh_max_deseasonalized_trend_7_lag_3_swan
#   832. swh_max_deseasonalized_trend_7_lag_5_swan
#   833. swh_max_deseasonalized_trend_7_lag_7_swan
#   834. swh_max_deseasonalized_trend_7_swan
#   835. swh_max_lag_14_swan
#   836. swh_max_lag_1_swan
#   837. swh_max_lag_3_swan
#   838. swh_max_lag_5_swan
#   839. swh_max_lag_7_swan
#   840. swh_max_ma_14_lag_14_swan
#   841. swh_max_ma_14_lag_1_swan
#   842. swh_max_ma_14_lag_3_swan
#   843. swh_max_ma_14_lag_5_swan
#   844. swh_max_ma_14_lag_7_swan
#   845. swh_max_ma_14_swan
#   846. swh_max_ma_2_lag_14_swan
#   847. swh_max_ma_2_lag_1_swan
#   848. swh_max_ma_2_lag_3_swan
#   849. swh_max_ma_2_lag_5_swan
#   850. swh_max_ma_2_lag_7_swan
#   851. swh_max_ma_2_swan
#   852. swh_max_ma_3_lag_14_swan
#   853. swh_max_ma_3_lag_1_swan
#   854. swh_max_ma_3_lag_3_swan
#   855. swh_max_ma_3_lag_5_swan
#   856. swh_max_ma_3_lag_7_swan
#   857. swh_max_ma_3_swan
#   858. swh_max_ma_5_lag_14_swan
#   859. swh_max_ma_5_lag_1_swan
#   860. swh_max_ma_5_lag_3_swan
#   861. swh_max_ma_5_lag_5_swan
#   862. swh_max_ma_5_lag_7_swan
#   863. swh_max_ma_5_swan
#   864. swh_max_ma_7_lag_14_swan
#   865. swh_max_ma_7_lag_1_swan
#   866. swh_max_ma_7_lag_3_swan
#   867. swh_max_ma_7_lag_5_swan
#   868. swh_max_ma_7_lag_7_swan
#   869. swh_max_ma_7_swan
#   870. swh_max_persistence_14_lag_14_swan
#   871. swh_max_persistence_14_lag_1_swan
#   872. swh_max_persistence_14_lag_3_swan
#   873. swh_max_persistence_14_lag_5_swan
#   874. swh_max_persistence_14_lag_7_swan
#   875. swh_max_persistence_14_swan
#   876. swh_max_persistence_2_lag_14_swan
#   877. swh_max_persistence_2_lag_1_swan
#   878. swh_max_persistence_2_lag_3_swan
#   879. swh_max_persistence_2_lag_5_swan
#   880. swh_max_persistence_2_lag_7_swan
#   881. swh_max_persistence_2_swan
#   882. swh_max_persistence_3_lag_14_swan
#   883. swh_max_persistence_3_lag_1_swan
#   884. swh_max_persistence_3_lag_3_swan
#   885. swh_max_persistence_3_lag_5_swan
#   886. swh_max_persistence_3_lag_7_swan
#   887. swh_max_persistence_3_swan
#   888. swh_max_persistence_5_lag_14_swan
#   889. swh_max_persistence_5_lag_1_swan
#   890. swh_max_persistence_5_lag_3_swan
#   891. swh_max_persistence_5_lag_5_swan
#   892. swh_max_persistence_5_lag_7_swan
#   893. swh_max_persistence_5_swan
#   894. swh_max_persistence_7_lag_14_swan
#   895. swh_max_persistence_7_lag_1_swan
#   896. swh_max_persistence_7_lag_3_swan
#   897. swh_max_persistence_7_lag_5_swan
#   898. swh_max_persistence_7_lag_7_swan
#   899. swh_max_persistence_7_swan
#   900. swh_max_rel_change_14_lag_14_swan
#   901. swh_max_rel_change_14_lag_1_swan
#   902. swh_max_rel_change_14_lag_3_swan
#   903. swh_max_rel_change_14_lag_5_swan
#   904. swh_max_rel_change_14_lag_7_swan
#   905. swh_max_rel_change_14_swan
#   906. swh_max_rel_change_3_lag_14_swan
#   907. swh_max_rel_change_3_lag_1_swan
#   908. swh_max_rel_change_3_lag_3_swan
#   909. swh_max_rel_change_3_lag_5_swan
#   910. swh_max_rel_change_3_lag_7_swan
#   911. swh_max_rel_change_3_swan
#   912. swh_max_rel_change_5_lag_14_swan
#   913. swh_max_rel_change_5_lag_1_swan
#   914. swh_max_rel_change_5_lag_3_swan
#   915. swh_max_rel_change_5_lag_5_swan
#   916. swh_max_rel_change_5_lag_7_swan
#   917. swh_max_rel_change_5_swan
#   918. swh_max_rel_change_7_lag_14_swan
#   919. swh_max_rel_change_7_lag_1_swan
#   920. swh_max_rel_change_7_lag_3_swan
#   921. swh_max_rel_change_7_lag_5_swan
#   922. swh_max_rel_change_7_lag_7_swan
#   923. swh_max_rel_change_7_swan
#   924. swh_max_rolling_mean_14_lag_14_swan
#   925. swh_max_rolling_mean_14_lag_1_swan
#   926. swh_max_rolling_mean_14_lag_3_swan
#   927. swh_max_rolling_mean_14_lag_5_swan
#   928. swh_max_rolling_mean_14_lag_7_swan
#   929. swh_max_rolling_mean_14_swan
#   930. swh_max_rolling_mean_3_lag_14_swan
#   931. swh_max_rolling_mean_3_lag_1_swan
#   932. swh_max_rolling_mean_3_lag_3_swan
#   933. swh_max_rolling_mean_3_lag_5_swan
#   934. swh_max_rolling_mean_3_lag_7_swan
#   935. swh_max_rolling_mean_3_swan
#   936. swh_max_rolling_mean_5_lag_14_swan
#   937. swh_max_rolling_mean_5_lag_1_swan
#   938. swh_max_rolling_mean_5_lag_3_swan
#   939. swh_max_rolling_mean_5_lag_5_swan
#   940. swh_max_rolling_mean_5_lag_7_swan
#   941. swh_max_rolling_mean_5_swan
#   942. swh_max_rolling_mean_7_lag_14_swan
#   943. swh_max_rolling_mean_7_lag_1_swan
#   944. swh_max_rolling_mean_7_lag_3_swan
#   945. swh_max_rolling_mean_7_lag_5_swan
#   946. swh_max_rolling_mean_7_lag_7_swan
#   947. swh_max_rolling_mean_7_swan
#   948. swh_max_swan
#   949. swh_max_trend_14_lag_14_swan
#   950. swh_max_trend_14_lag_1_swan
#   951. swh_max_trend_14_lag_3_swan
#   952. swh_max_trend_14_lag_5_swan
#   953. swh_max_trend_14_lag_7_swan
#   954. swh_max_trend_14_swan
#   955. swh_max_trend_3_lag_14_swan
#   956. swh_max_trend_3_lag_1_swan
#   957. swh_max_trend_3_lag_3_swan
#   958. swh_max_trend_3_lag_5_swan
#   959. swh_max_trend_3_lag_7_swan
#   960. swh_max_trend_3_swan
#   961. swh_max_trend_5_lag_14_swan
#   962. swh_max_trend_5_lag_1_swan
#   963. swh_max_trend_5_lag_3_swan
#   964. swh_max_trend_5_lag_5_swan
#   965. swh_max_trend_5_lag_7_swan
#   966. swh_max_trend_5_swan
#   967. swh_max_trend_7_lag_14_swan
#   968. swh_max_trend_7_lag_1_swan
#   969. swh_max_trend_7_lag_3_swan
#   970. swh_max_trend_7_lag_5_swan
#   971. swh_max_trend_7_lag_7_swan
#   972. swh_max_trend_7_swan
#
# 📊 Feature breakdown:
#   Basic features: 2
#   Enhanced features: 34
#   Excluded features: 936
#
# 📋 Sample enhanced features (after filtering):
#     - anom_swh_max_abs_change_14_swan
#     - anom_swh_max_abs_change_3_swan
#     - anom_swh_max_abs_change_5_swan
#     - anom_swh_max_abs_change_7_swan
#     - anom_swh_max_ma_14_swan
#     - anom_swh_max_ma_2_swan
#     - anom_swh_max_ma_3_swan
#     - anom_swh_max_ma_5_swan
#     - anom_swh_max_ma_7_swan
#     - anom_swh_max_rel_change_14_swan
#     ... and 24 more
#
# 🚫 Sample excluded features:
#     - anom_swh_max_abs_change_14_lag_14_swan
#     - anom_swh_max_abs_change_14_lag_1_swan
#     - anom_swh_max_abs_change_14_lag_3_swan
#     - anom_swh_max_abs_change_14_lag_5_swan
#     - anom_swh_max_abs_change_14_lag_7_swan
#     ... and 931 more
#
# ✅ Using 36 features for rule evaluation
# 🔧 Generating rules from 36 features...
# ✅ Added 36 single-feature rules
# ✅ Added 630 double-feature AND rules
# ✅ Added 630 double-feature OR rules
# 🎯 Total rules generated: 1296
#    Single rules: 36
#    Double rules: 1260
# 📅 Creating 6-fold cross-validation splits...
# ✅ Using TimeSeriesSplit
# 🚀 Evaluating 1296 rules using 10 cores...
# 📊 Progress: 50/1296 rules evaluated
# 📊 Progress: 100/1296 rules evaluated
# 📊 Progress: 150/1296 rules evaluated
# 📊 Progress: 200/1296 rules evaluated
# 📊 Progress: 250/1296 rules evaluated
# 📊 Progress: 300/1296 rules evaluated
# 📊 Progress: 350/1296 rules evaluated
# 📊 Progress: 400/1296 rules evaluated
# 📊 Progress: 450/1296 rules evaluated
# 📊 Progress: 500/1296 rules evaluated
# 📊 Progress: 550/1296 rules evaluated
# 📊 Progress: 600/1296 rules evaluated
# 📊 Progress: 650/1296 rules evaluated
# 📊 Progress: 700/1296 rules evaluated
# 📊 Progress: 750/1296 rules evaluated
# 📊 Progress: 800/1296 rules evaluated
# 📊 Progress: 850/1296 rules evaluated
# 📊 Progress: 900/1296 rules evaluated
# 📊 Progress: 950/1296 rules evaluated
# 📊 Progress: 1000/1296 rules evaluated
# 📊 Progress: 1050/1296 rules evaluated
# 📊 Progress: 1100/1296 rules evaluated
# 📊 Progress: 1150/1296 rules evaluated
# 📊 Progress: 1200/1296 rules evaluated
# 📊 Progress: 1250/1296 rules evaluated
# ✅ Evaluation complete: 1296 successful rules
# ⏱️ Evaluation completed in 0:09:25.056873
# 💾 Saving results...
# ✅ Main results saved: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/simplified_rule_cv_results.csv
# ✅ Fold thresholds saved: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/simplified_fold_thresholds.csv
#
# 🎉 SIMPLIFIED RULE EVALUATION COMPLETE!
# ================================================================================
# 📊 Total rules evaluated: 1296
# 🏆 Best F1 score: 0.659
# 📈 Rules with F1 > 0.5: 885
# 📁 Results saved to: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/simplified_rule_cv_results.csv
#
# 🏆 TOP 10 RULES:
#                                                rule_name rule_type  f1_mean  precision_mean  recall_mean
#       (swh_max_swan > t1) OR (swh_max_trend_3_swan > t2)        or 0.658960        0.624142     0.711490
#  (swh_max_abs_change_3_swan > t1) OR (swh_max_swan > t2)        or 0.654519        0.601892     0.734243
#  (swh_max_abs_change_7_swan > t1) OR (swh_max_swan > t2)        or 0.653542        0.578630     0.761851
#          (swh_max_ma_2_swan > t1) OR (swh_max_swan > t2)        or 0.652357        0.571585     0.774324
#  (swh_max_abs_change_5_swan > t1) OR (swh_max_swan > t2)        or 0.652240        0.577464     0.767791
#                                 swh_max_swan > threshold    single 0.651384        0.571636     0.771546
#          (swh_max_ma_3_swan > t1) OR (swh_max_swan > t2)        or 0.650690        0.588269     0.751407
#          (anom_swh_max_swan > t1) OR (swh_max_swan > t2)        or 0.649345        0.568248     0.771546
#     (anom_swh_max_ma_2_swan > t1) OR (swh_max_swan > t2)        or 0.649070        0.568042     0.771546
# (swh_max_abs_change_14_swan > t1) OR (swh_max_swan > t2)        or 0.648986        0.597412     0.722031
#
# 🎉 Simplified rule evaluation completed!

# %%
import pandas as pd

# Read the results CSV produced by the rule evaluation step
results_path = "/Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/simplified_rule_cv_results.csv"
results_df = pd.read_csv(results_path)

# Show the top 5 rows as a quick check
print("Top 5 rows of the results:")
display(results_df.head())
# Out:
# Top 5 rows of the results:
#    rule_idx                                          rule_name rule_type  \
# 0      1287  (swh_max_swan > t1) OR (swh_max_trend_3_swan >...        or
# 1      1171  (swh_max_abs_change_3_swan > t1) OR (swh_max_s...        or
# 2      1200  (swh_max_abs_change_7_swan > t1) OR (swh_max_s...        or
# 3      1225    (swh_max_ma_2_swan > t1) OR (swh_max_swan > t2)        or
# 4      1186  (swh_max_abs_change_5_swan > t1) OR (swh_max_s...        or
#
#    complexity  n_folds_successful  accuracy_mean  precision_mean  recall_mean  \
# 0           2                   6       0.818721        0.624142     0.711490
# 1           2                   6       0.808219        0.601892     0.734243
# 2           2                   6       0.799543        0.578630     0.761851
# 3           2                   6       0.796804        0.571585     0.774324
# 4           2                   6       0.797260        0.577464     0.767791
#
#     f1_mean  accuracy_std  ...  threshold_swh_max_trend_14_swan_max  \
# 0  0.658960      0.044835  ...                                  NaN
# 1  0.654519      0.047163  ...                                  NaN
# 2  0.653542      0.051655  ...                                  NaN
# 3  0.652357      0.049553  ...                                  NaN
# 4  0.652240      0.053172  ...                                  NaN
#
#    threshold_swh_max_trend_3_swan  threshold_swh_max_trend_3_swan_min  \
# 0                           0.262                               0.179
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
#
#   threshold_swh_max_trend_3_swan_max threshold_swh_max_trend_5_swan  \
# 0                             0.3032                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   threshold_swh_max_trend_5_swan_min  threshold_swh_max_trend_5_swan_max  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    threshold_swh_max_trend_7_swan  threshold_swh_max_trend_7_swan_min  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
#
#    threshold_swh_max_trend_7_swan_max
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 124 columns]

# %%
# 3. AEP Calculation (Rule & ML)
# %env PYTHONPATH=.
# %env RUN_PATH=run_g8
# %env MIN_DAYS=3
# !python3 scripts/aep_calculation.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g3
# env: MIN_DAYS=3
# [AEP] Aggregated N_PARAM (fishermen): 14424.0
# [AEP] Aggregated W_PARAM (wage): 11.269387755102041
#
# 🔧 AEP_CALCULATION.PY - Final AEP Analysis
# Run: run_g3
# Reference port: CALETA_TIERRA_COLORADA
# ✅ Best single rule: anom_swh_min_swan > 0.225
#
# 🚀 Running speed-optimized AEP simulation...
# 🚀 SPEED-OPTIMIZED UNIFIED AEP ANALYSIS
# ==================================================
#   Data: 2341 observations
#   Trigger: anom_swh_min_swan > 0.22494295115257257
#   Port: 14424.0 fishermen × $11.269387755102041/day
#   Min event: 3 days
#   Block length: 4 days
#   Simulations: 4000
#   Using 2341 days for simulation.
#   Observed events: 50 out of 2341 days
#   Pre-computing trigger values...
#   Generating block bootstrap samples...
#   Pre-computing valid block positions...
#   Generating all simulation indices...
#   Processing 4000 simulations using 12 parallel workers...
#   Using 12 threads for parallel processing...
# Processing batches: 100%|███████████████████████| 13/13 [00:00<00:00, 50.01it/s]
#   Completed 4000 simulations successfully.
#   Calculating standard AEP curve...
#
# 📊 Standard AEP Results:
#   Mean annual loss: $605,944
#   Max annual loss: $3,250,993
#   Zero loss probability: 31.3%
#   Calculating confusion matrix AEP curves...
#
# 🔍 Confusion Matrix Results:
#   FP Cost: $224,603
#   FN Cost: $82,453
#   TP Cost: $108,136
#   Total Insurance Cost: $332,739
#
# 📊 Average Event Counts per Simulation:
#   FP Events (False Alarms): 12.4
#   FN Events (Missed): 2.6
#   TP Events (Correct): 2.9
#   Total Events: 17.9
# ✅ Using ML probabilities: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g10/ML_probs_2024.csv
# ✅ Using ML optimal threshold: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g10/ML_probs_2024_optimal_threshold.txt
# ✅ Loaded ML optimal threshold: 0.31359999999999977
#
# 🚀 Running ML-based AEP simulation (logistic regression probabilities)...
# 🚀 SPEED-OPTIMIZED UNIFIED AEP ANALYSIS
# ==================================================
#   Data: 150 observations
#   Trigger: calibrated_probability > 0.31359999999999977
#   Port: 14424.0 fishermen × $11.269387755102041/day
#   Min event: 3 days
#   Block length: 4 days
#   Simulations: 4000
#   Using 150 days for simulation.
#   Observed events: 8 out of 150 days
#   Pre-computing trigger values...
#   Generating block bootstrap samples...
#   Pre-computing valid block positions...
#   Generating all simulation indices...
#   Processing 4000 simulations using 12 parallel workers...
#   Using 12 threads for parallel processing...
# Processing batches: 100%|█████████████████████| 13/13 [00:00<00:00, 2398.96it/s]
#   Completed 4000 simulations successfully.
#   Calculating standard AEP curve...
#
# 📊 Standard AEP Results:
#   Mean annual loss: $7,914,502
#   Max annual loss: $10,565,727
#   Zero loss probability: 0.0%
#   Calculating confusion matrix AEP curves...
#
# 🔍 Confusion Matrix Results:
#   FP Cost: $7,810,023
#   FN Cost: $3,019,319
#   TP Cost: $0
#   Total Insurance Cost: $7,810,023
#
# 📊 Average Event Counts per Simulation:
#   FP Events (False Alarms): 20.4
#   FN Events (Missed): 8.0
#   TP Events (Correct): 1.4
#   Total Events: 29.8
# ✅ Saved ML AEP summary: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/ml_aep_summary_20250720_201045.csv
# ✅ Saved ML AEP curve: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/ml_aep_curve_20250720_201045.csv
#
# ===== FINAL AEP SIMULATION SUMMARY =====
# Rule-based method: mean annual loss = $605,944
# ML-based method: mean annual loss = $7,914,502
# ✅ Saved summary: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/aep_summary_20250720_201045.csv
# ✅ Saved AEP curve: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/aep_curve_20250720_201045.csv
# ✅ Saved observed yearly losses: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/observed_yearly_losses_20250720_201045.csv
#
# 🎉 AEP calculation completed!

# %%
# 3. AEP Calculation (ML)
# %env PYTHONPATH=.
# %env PYTHONPATH=.
# %env RUN_PATH=run_g3
# %env MIN_DAYS=3
# !python3 scripts/aep_ml_calculation.py
# Out:
# env: PYTHONPATH=.
# env: PYTHONPATH=.
# env: RUN_PATH=run_g3
# env: MIN_DAYS=3
# [ML-AEP] N_PARAM (fishermen): 1482.0
# [ML-AEP] W_PARAM (wage): 50.2
#
# 🎲 ENHANCED ML AEP CALCULATOR - Independent Daily Draws
# ======================================================================
# This uses the THEORETICALLY CORRECT approach for ML probabilities:
# • Each day's probability = P(port closes | features)
# • Independent random draws (no block bootstrap)
# • Temporal correlation already captured in ML features
# • Enhanced output matching other simulation scripts
# ======================================================================
# Run: run_g3
# Reference port: CALETA_TIERRA_COLORADA
# ✅ Using ML probabilities: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g10/ML_probs_2024.csv
# ✅ Using optimal threshold: 0.3136
# ✅ Loaded ML probabilities: (366, 9)
# ✅ Merged data: (150, 8497)
#    Date range: 2024-01-01 00:00:00 to 2024-05-29 00:00:00
# ✅ Found observed events: 8 out of 150 days
#
# 🎲 Running ENHANCED ML AEP simulation...
# 🎲 CORRECTED ML AEP ANALYSIS (Independent Daily Draws)
# ============================================================
#   Daily probabilities: 150 days
#   Probability range: 0.0063 to 0.8859
#   Mean probability: 0.1746
#   Simulations: 4000
#   Economic params: 1482.0 fishermen × $50.2/day
#   Completed 0/4000 simulations...
#   Completed 1000/4000 simulations...
#   Completed 2000/4000 simulations...
#   Completed 3000/4000 simulations...
#   ✅ Completed 4000 simulations
#
# 📊 Enhanced ML AEP Results:
#   Mean annual loss: $447,736
#   P99 annual loss: $1,190,342
#   Max annual loss: $1,487,928
#   Zero loss probability: 12.3%
#   Mean events per year: 18.1
#   P99 events per year: 25.0
#   Mean event days per year: 26.1
#   P99 event days per year: 36.0
#
# 🔍 Enhanced Confusion Matrix Analysis...
#   Using optimal threshold: 0.3136
#   Observed confusion matrix: TP=1, FP=26, TN=116, FN=7
#   Observed metrics: Precision=0.037, Recall=0.125, F1=0.057
#   Simulated costs - TP: $148,793, FP: $169,083, FN: $185,991
#
# 📅 Observed Yearly Losses:
#   2024: $446,378
#   Average: $446,378
#
# ✅ Saved enhanced ML AEP summary: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/enhanced_ml_aep_summary_20250720_201142.csv
# ✅ Saved enhanced ML AEP curve: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/enhanced_ml_aep_curve_20250720_201142.csv
# ✅ Saved enhanced ML observed yearly losses: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/enhanced_ml_observed_yearly_losses_20250720_201142.csv
# ✅ Saved enhanced ML confusion matrix: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/enhanced_ml_confusion_matrix_20250720_201142.csv
#
# ===== ENHANCED ML AEP SUMMARY =====
# Method: Independent daily probability draws
# Mean annual loss: $447,736
# P99 annual loss: $1,190,342
# Zero loss probability: 12.3%
# Mean events per year: 18.1
# P99 events per year: 25.0
# Simulations: 4000
# Observed F1 Score: 0.057
# Optimal Threshold: 0.3136
#
# 🎉 Enhanced ML AEP calculation completed!
# This approach correctly treats ML probabilities as daily event probabilities
# and provides comprehensive metrics matching other simulation scripts.

# %%
# 5. AEP calculation for multiple conditions

# %env PYTHONPATH=.
# %env RUN_PATH=run_g8
# %env MIN_DAYS=3
# !python3 scripts/aep_calculation_experiment.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g8
# env: MIN_DAYS=3
# [AEP] Aggregated N_PARAM (fishermen): 183.0
# [AEP] Aggregated W_PARAM (wage): 12.785714285714286
#
# 🚀 ENHANCED MULTI-RULE AEP ANALYSIS (Keeping Working Parts)
# Run: run_g8
# Reference port: CALETA_NAZCA
#
# 📋 Generating rule combinations...
#   Top features: ['swh_max_swan', 'swh_p80_swan', 'anom_swh_max_waverys']
#   Testing 15 double rule combinations...
#
# --- 1/15: double_AND ---
#     F1: 0.633
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 844 out of 2557 days (33.0%)
# 📊 Observed confusion matrix: TP=463, FP=381, TN=1556, FN=157
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $209,378, P99 loss: $306,535
#
# --- 2/15: double_OR ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 895 out of 2557 days (35.0%)
# 📊 Observed confusion matrix: TP=477, FP=418, TN=1519, FN=143
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $220,590, P99 loss: $322,890
#
# --- 3/15: double_AND ---
#     F1: 0.629
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 887 out of 2557 days (34.7%)
# 📊 Observed confusion matrix: TP=474, FP=413, TN=1524, FN=146
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $226,566, P99 loss: $325,230
#
# --- 4/15: double_OR ---
#     F1: 0.628
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 889 out of 2557 days (34.8%)
# 📊 Observed confusion matrix: TP=474, FP=415, TN=1522, FN=146
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $227,263, P99 loss: $327,570
#
# --- 5/15: double_AND ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 882 out of 2557 days (34.5%)
# 📊 Observed confusion matrix: TP=473, FP=409, TN=1528, FN=147
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $225,646, P99 loss: $325,230
#
# --- 6/15: double_OR ---
#     F1: 0.628
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 889 out of 2557 days (34.8%)
# 📊 Observed confusion matrix: TP=474, FP=415, TN=1522, FN=146
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $227,263, P99 loss: $327,570
#
# --- 7/15: double_AND ---
#     F1: 0.628
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 889 out of 2557 days (34.8%)
# 📊 Observed confusion matrix: TP=474, FP=415, TN=1522, FN=146
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $227,263, P99 loss: $327,570
#
# --- 8/15: double_OR ---
#     F1: 0.628
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 889 out of 2557 days (34.8%)
# 📊 Observed confusion matrix: TP=474, FP=415, TN=1522, FN=146
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $227,263, P99 loss: $327,570
#
# --- 9/15: double_AND ---
#     F1: 0.633
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 868 out of 2557 days (33.9%)
# 📊 Observed confusion matrix: TP=471, FP=397, TN=1540, FN=149
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $218,885, P99 loss: $318,234
#
# --- 10/15: double_OR ---
#     F1: 0.628
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 889 out of 2557 days (34.8%)
# 📊 Observed confusion matrix: TP=474, FP=415, TN=1522, FN=146
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $227,263, P99 loss: $327,570
#
# --- 11/15: double_AND ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 891 out of 2557 days (34.8%)
# 📊 Observed confusion matrix: TP=476, FP=415, TN=1522, FN=144
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $219,208, P99 loss: $320,551
#
# --- 12/15: double_OR ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 895 out of 2557 days (35.0%)
# 📊 Observed confusion matrix: TP=477, FP=418, TN=1519, FN=143
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $220,590, P99 loss: $322,890
#
# --- 13/15: double_AND ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 895 out of 2557 days (35.0%)
# 📊 Observed confusion matrix: TP=477, FP=418, TN=1519, FN=143
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $220,590, P99 loss: $322,890
#
# --- 14/15: double_OR ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 895 out of 2557 days (35.0%)
# 📊 Observed confusion matrix: TP=477, FP=418, TN=1519, FN=143
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $220,590, P99 loss: $322,890
#
# --- 15/15: double_AND ---
#     F1: 0.630
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 895 out of 2557 days (35.0%)
# 📊 Observed confusion matrix: TP=477, FP=418, TN=1519, FN=143
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
#     ✅ Mean loss: $220,590, P99 loss: $322,890
#
# 🎯 Generating detailed outputs for best combination...
#   🚀 Enhanced multi-rule AEP: 2 features, 4000 sims
# 📊 Observed events: 620 out of 2557 days
# 📊 Rule predictions: 844 out of 2557 days (33.0%)
# 📊 Observed confusion matrix: TP=463, FP=381, TN=1556, FN=157
# 🔄 Running enhanced simulation with detailed tracking...
# ✅ Completed 4000 simulations
# ✅ Saved observed yearly losses: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/multi_rule_observed_yearly_losses_20250721_093511.csv
# ✅ Saved enhanced AEP curve: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/multi_rule_aep_curve_20250721_093511.csv
# ✅ Saved enhanced AEP summary: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/multi_rule_aep_summary_20250721_093511.csv
#
# 🏆 TOP 5 ENHANCED MULTI-RULE COMBINATIONS:
# ======================================================================
# 1. double_AND: swh_max_swan > t1 AND swh_p80_swan > t2
#    F1: 0.633 | Mean Loss: $209,378 | P99 Loss: $306,535
#    Events: 121.1 | Zero Prob: 0.0%
#    CM: TP=66.4, FP=54.8, FN=22.1
#
# 2. double_AND: swh_max_swan > t1 AND anom_swh_p80_swan > t2
#    F1: 0.633 | Mean Loss: $218,885 | P99 Loss: $318,234
#    Events: 124.6 | Zero Prob: 0.0%
#    CM: TP=67.5, FP=57.1, FN=21.0
#
# 3. double_AND: swh_p80_swan > t1 AND anom_swh_max_waverys > t2
#    F1: 0.630 | Mean Loss: $219,208 | P99 Loss: $320,551
#    Events: 127.8 | Zero Prob: 0.0%
#    CM: TP=68.2, FP=59.6, FN=20.2
#
# 4. double_OR: swh_max_swan > t1 OR swh_p80_swan > t2
#    F1: 0.630 | Mean Loss: $220,590 | P99 Loss: $322,890
#    Events: 128.4 | Zero Prob: 0.0%
#    CM: TP=68.4, FP=60.0, FN=20.1
#
# 5. double_OR: swh_p80_swan > t1 OR anom_swh_max_waverys > t2
#    F1: 0.630 | Mean Loss: $220,590 | P99 Loss: $322,890
#    Events: 128.4 | Zero Prob: 0.0%
#    CM: TP=68.4, FP=60.0, FN=20.1
#
# ✅ Results saved: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g8/enhanced_multi_rule_complete_summary_20250721_093511.csv

# %%
# 5. Plot Pipeline Summary
# %env PYTHONPATH=.
# %env RUN_PATH=run_g8
# %env MIN_DAYS=1
# !python3 scripts/plot_pipeline_summary.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g3
# env: MIN_DAYS=1
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/swh_max_swan_vs_waverys_events.png
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/densities_swan_vs_waverys.png
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/anom_swh_max_swan_vs_waverys_events.png
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/densities_anom_swh_max_swan_vs_waverys.png
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/scatter_swh_max_swan_vs_waverys.png
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/scatter_anom_swh_max_swan_vs_waverys.png
# DEBUG: observed losses loaded:
#    year  observed_loss
# 0  2018   1.137848e+06
# 1  2019   1.625496e+05
# 2  2020   4.876489e+05
# 3  2021   2.275695e+06
# 4  2022   3.250993e+05
# 5  2023   2.438245e+06
# 6  2024   2.600794e+06
# ✅ Saved plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/aep_with_observed_losses.png
# 📊 Multi-condition AEP plot data:
#    Best multi-rule: anom_swh_min_swan > t1 AND swh_max_swan > t2
#    Best mean loss: $1,711,241
#    Using single rule AEP curve with 4000 points
#    Improvement ratio: 0.539 (lower is better)
# DEBUG: observed losses loaded for multi-condition plot:
#    year  observed_loss
# 0  2018   1.137848e+06
# 1  2019   1.625496e+05
# 2  2020   4.876489e+05
# 3  2021   2.275695e+06
# 4  2022   3.250993e+05
# 5  2023   2.438245e+06
# 6  2024   2.600794e+06
# ✅ Saved multi-condition AEP plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/multi_condition_aep_with_observed_losses.png
# ✅ Saved multi-condition AEP curve data: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/multi_condition_aep_curve_best.csv
# 📊 Multi-condition only AEP plot:
#    Best multi-rule: anom_swh_min_swan > t1 AND swh_max_swan > t2
#    Best mean loss: $1,711,241
# DEBUG: observed losses loaded for multi-condition only plot:
#    year  observed_loss
# 0  2018   1.137848e+06
# 1  2019   1.625496e+05
# 2  2020   4.876489e+05
# 3  2021   2.275695e+06
# 4  2022   3.250993e+05
# 5  2023   2.438245e+06
# 6  2024   2.600794e+06
# ✅ Saved multi-condition only AEP plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/multi_condition_aep_only.png
# 📊 Creating comprehensive AEP comparison plot...
#    ✅ Added Single Rule AEP curve
#    ✅ Added Multi-Rule AEP curve: double_AND
#    ✅ Added ML AEP curve
# DEBUG: observed losses loaded for comparison plot:
#    year  observed_loss
# 0  2018   1.137848e+06
# 1  2019   1.625496e+05
# 2  2020   4.876489e+05
# 3  2021   2.275695e+06
# 4  2022   3.250993e+05
# 5  2023   2.438245e+06
# 6  2024   2.600794e+06
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:741: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:741: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:745: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=300, bbox_inches='tight')
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:745: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=300, bbox_inches='tight')
# ✅ Saved comprehensive AEP comparison plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/aep_comparison_all_methods.png
# ✅ Saved AEP methods comparison summary: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/aep_methods_comparison_summary.csv
#
# 📊 AEP Methods Ranking:
#    1. Machine Learning: $260K (+93.6%)
#    2. Multi-Rule (double_AND): $1711K (+57.8%)
#    3. Single Rule: $4051K (+0.0%)
# 📊 Creating Confusion Matrix Component AEP plot...
#    Using confusion matrix costs: FP=$2,436,619, FN=$605,254, TP=$634,960
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:953: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:953: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:957: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=300, bbox_inches='tight')
# /Users/ageidv/suyana/peru_swan/scripts/plot_pipeline_summary.py:957: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=300, bbox_inches='tight')
# ✅ Saved confusion matrix AEP components plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/confusion_matrix_aep_components.png
# ✅ Saved confusion matrix cost breakdown: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/confusion_matrix_cost_breakdown.csv
#
# 📊 CORRECTED Confusion Matrix Cost Analysis:
#    Closure Costs (FP + TP): $3,071,579
#    📉 False Positives: $2,436,619 (79.3% of closure costs)
#    📈 True Positives:  $634,960 (20.7% of closure costs)
#    📊 Separate Analysis:
#    📉 False Negatives: $605,254 (missed events - separate cost)
#    🎯 Key Insight: FP costs are 3.8x higher than TP costs
#    💡 Implication: Most closure costs come from false alarms
#
# ================================================================================
# 📊 COMPREHENSIVE CONFUSION MATRIX COMPARISON
# ================================================================================
# 🔍 Searching for Single Rule confusion matrix data...
# ✅ Extracted Single Rule data from multi-threshold summary
# 🔍 DEBUGGING MULTI-RULE FILES
# ==================================================
# Found 10 potential multi-rule files:
#   📁 enhanced_multi_rule_summary_20250711_143735.csv
#   📁 enhanced_multi_rule_summary_20250712_140307.csv
#   📁 enhanced_multi_rule_summary_20250713_022012.csv
#   📁 fast_multi_rule_summary_20250711_143436.csv
#   📁 baseline_comparison_20250711_143735.csv
#   📁 baseline_comparison_20250712_140307.csv
#   📁 baseline_comparison_20250713_022012.csv
#   📁 detailed_top_combinations_20250711_143735.csv
#   📁 detailed_top_combinations_20250712_140307.csv
#   📁 detailed_top_combinations_20250713_022012.csv
#
# 📋 EXAMINING: enhanced_multi_rule_summary_20250711_143735.csv
#    Shape: (20, 9)
#    Columns: ['combination_id', 'type', 'description', 'features', 'thresholds', 'f1_score', 'mean_loss', 'max_loss', 'zero_prob']
#    First row sample:
#      combination_id: 0
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      max_loss: 4388840.522448979
#      zero_prob: 0.0
#    Rule-related columns: ['type', 'description', 'features', 'thresholds']
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 📋 EXAMINING: enhanced_multi_rule_summary_20250712_140307.csv
#    Shape: (20, 9)
#    Columns: ['combination_id', 'type', 'description', 'features', 'thresholds', 'f1_score', 'mean_loss', 'max_loss', 'zero_prob']
#    First row sample:
#      combination_id: 0
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      max_loss: 4388840.522448979
#      zero_prob: 0.0
#    Rule-related columns: ['type', 'description', 'features', 'thresholds']
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 📋 EXAMINING: enhanced_multi_rule_summary_20250713_022012.csv
#    Shape: (20, 9)
#    Columns: ['combination_id', 'type', 'description', 'features', 'thresholds', 'f1_score', 'mean_loss', 'max_loss', 'zero_prob']
#    First row sample:
#      combination_id: 0
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      max_loss: 4388840.522448979
#      zero_prob: 0.0
#    Rule-related columns: ['type', 'description', 'features', 'thresholds']
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 📋 EXAMINING: fast_multi_rule_summary_20250711_143436.csv
#    Shape: (15, 9)
#    Columns: ['combination_id', 'type', 'description', 'features', 'thresholds', 'f1_score', 'mean_loss', 'max_loss', 'zero_prob']
#    First row sample:
#      combination_id: 0
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      max_loss: 4388840.522448979
#      zero_prob: 0.0
#    Rule-related columns: ['type', 'description', 'features', 'thresholds']
#      type: double_AND
#      description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 📋 EXAMINING: baseline_comparison_20250711_143735.csv
#    Shape: (4, 5)
#    Columns: ['analysis_type', 'description', 'f1_score', 'mean_loss', 'improvement_vs_single']
#    First row sample:
#      analysis_type: single_rule
#      description: anom_swh_min_swan > 0.2249
#      f1_score: 0.3036649214659686
#      mean_loss: 3176220.141061225
#      improvement_vs_single: 0.0
#    Rule-related columns: ['analysis_type', 'description']
#      analysis_type: single_rule
#      description: anom_swh_min_swan > 0.2249
#
# 📋 EXAMINING: baseline_comparison_20250712_140307.csv
#    Shape: (4, 5)
#    Columns: ['analysis_type', 'description', 'f1_score', 'mean_loss', 'improvement_vs_single']
#    First row sample:
#      analysis_type: single_rule
#      description: anom_swh_min_swan > 0.2249
#      f1_score: 0.3036649214659686
#      mean_loss: 3176220.141061225
#      improvement_vs_single: 0.0
#    Rule-related columns: ['analysis_type', 'description']
#      analysis_type: single_rule
#      description: anom_swh_min_swan > 0.2249
#
# 📋 EXAMINING: baseline_comparison_20250713_022012.csv
#    Shape: (4, 5)
#    Columns: ['analysis_type', 'description', 'f1_score', 'mean_loss', 'improvement_vs_single']
#    First row sample:
#      analysis_type: single_rule
#      description: anom_swh_min_swan > 0.2249
#      f1_score: 0.3036649214659686
#      mean_loss: 3176220.141061225
#      improvement_vs_single: 0.0
#    Rule-related columns: ['analysis_type', 'description']
#      analysis_type: single_rule
#      description: anom_swh_min_swan > 0.2249
#
# 📋 EXAMINING: detailed_top_combinations_20250711_143735.csv
#    Shape: (3, 7)
#    Columns: ['rank', 'features', 'thresholds', 'f1_score', 'mean_loss', 'prediction_rate', 'total_predictions']
#    First row sample:
#      rank: 1
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      prediction_rate: 0.026984747751271
#      total_predictions: 69
#    Rule-related columns: ['features', 'thresholds']
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 📋 EXAMINING: detailed_top_combinations_20250712_140307.csv
#    Shape: (3, 7)
#    Columns: ['rank', 'features', 'thresholds', 'f1_score', 'mean_loss', 'prediction_rate', 'total_predictions']
#    First row sample:
#      rank: 1
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      prediction_rate: 0.026984747751271
#      total_predictions: 69
#    Rule-related columns: ['features', 'thresholds']
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 📋 EXAMINING: detailed_top_combinations_20250713_022012.csv
#    Shape: (3, 7)
#    Columns: ['rank', 'features', 'thresholds', 'f1_score', 'mean_loss', 'prediction_rate', 'total_predictions']
#    First row sample:
#      rank: 1
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#      f1_score: 0.3307086614173228
#      mean_loss: 1711241.429632653
#      prediction_rate: 0.026984747751271
#      total_predictions: 69
#    Rule-related columns: ['features', 'thresholds']
#      features: ['anom_swh_min_swan', 'swh_max_swan']
#      thresholds: (np.float64(0.2320103971666665), np.float64(1.575))
#
# 🔧 MANUAL MULTI-RULE CONFUSION MATRIX CALCULATION
# ==================================================
# ✅ Loaded data: (2341, 8497)
# 📊 Observed events: 50 out of 2341 days
# 📋 Baseline comparison file: (4, 5)
# 📝 Multi-rule description: anom_swh_min_swan > t1 AND swh_max_swan > t2
#
# 🧪 Testing: anom_swh_p80_swan AND anom_swh_max_swan
#    📊 TP=40, FP=333, TN=1958, FN=10
#    📈 F1=0.189, Precision=0.107, Recall=0.800
#
# 🧪 Testing: anom_swh_min_swan AND swh_max_swan
#    📊 TP=22, FP=60, TN=2231, FN=28
#    📈 F1=0.333, Precision=0.268, Recall=0.440
#
# 🧪 Testing: anom_swh_p80_swan AND swh_max_swan
#    📊 TP=27, FP=137, TN=2154, FN=23
#    📈 F1=0.252, Precision=0.165, Recall=0.540
#
# ✅ BEST MULTI-RULE RESULT:
#    Rule: Multi-Rule (double_AND): anom_swh_min_swan AND swh_max_swan
#    F1 Score: 0.333
#    Confusion Matrix: TP=22, FP=60, TN=2231, FN=28
# 🔍 Searching for Multi-Rule confusion matrix data...
# ✅ Calculated Multi-Rule confusion matrix: Multi-Rule (double_AND): anom_swh_min_swan & swh_max_swan
#    TP=22, FP=63, TN=2228, FN=28
# 🔍 Searching for ML confusion matrix data...
# 🔧 Calculating ML confusion matrix for FULL dataset...
# ✅ Loaded full dataset: (2341, 8497)
# 📊 Using top 15 features for ML simulation
# 📈 Dataset summary: 2341 samples, 50 events (2.1%)
# 🤖 Training ML models with time series CV...
# 🎯 Finding optimal threshold...
# ✅ Optimal threshold: 0.758 (F1: 0.302)
# 📊 Full Dataset ML Confusion Matrix: TP=24, FP=85, TN=2206, FN=26
# ✅ Added ML data: Machine Learning (Full Dataset CV)
#    Dataset size: 2341 samples
#
# 📊 Found confusion matrix data for 3 methods
# ✅ Saved confusion matrix comparison: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/confusion_matrix_comparison_all_methods.csv
#
# 📋 CORRECTED CONFUSION MATRIX COMPARISON TABLE
# ========================================================================================================================
#                                                    Method  Obs_TP  Obs_FP  Obs_TN  Obs_FN Accuracy Precision Recall F1_Score
#                     Single Rule (Best: anom_swh_p80_swan)      28     158    2341      30    0.926     0.151  0.483    0.230
# Multi-Rule (double_AND): anom_swh_min_swan & swh_max_swan      22      63    2228      28    0.961     0.259  0.440    0.326
#                        Machine Learning (Full Dataset CV)      24      85    2206      26    0.953     0.220  0.480    0.302
#
# 📊 DETAILED PERFORMANCE BREAKDOWN
# ------------------------------------------------------------
#
# 🔹 Single Rule (Best: anom_swh_p80_swan):
#    Confusion Matrix: TP=28, FP=158, TN=2341, FN=30
#    Performance: Acc=0.926, Prec=0.151, Rec=0.483, F1=0.230
#    Dataset: 2557 total days
#    Event Rate: 2.3% (58 actual events)
#    Prediction Rate: 7.3% (186 predicted events)
#    Error Breakdown: 84.0% False Positives, 16.0% False Negatives
#
# 🔹 Multi-Rule (double_AND): anom_swh_min_swan & swh_max_swan:
#    Confusion Matrix: TP=22, FP=63, TN=2228, FN=28
#    Performance: Acc=0.961, Prec=0.259, Rec=0.440, F1=0.326
#    Dataset: 2341 total days
#    Event Rate: 2.1% (50 actual events)
#    Prediction Rate: 3.6% (85 predicted events)
#    Error Breakdown: 69.2% False Positives, 30.8% False Negatives
#
# 🔹 Machine Learning (Full Dataset CV):
#    Confusion Matrix: TP=24, FP=85, TN=2206, FN=26
#    Performance: Acc=0.953, Prec=0.220, Rec=0.480, F1=0.302
#    Dataset: 2341 total days
#    Event Rate: 2.1% (50 actual events)
#    Prediction Rate: 4.7% (109 predicted events)
#    Error Breakdown: 76.6% False Positives, 23.4% False Negatives
#
# 🏆 METHOD RANKING BY F1 SCORE
# ----------------------------------------
#    1. Multi-Rule (double_AND): anom_swh_min_swan & swh_max_swan: F1 = 0.326
#    2. Machine Learning (Full Dataset CV): F1 = 0.302
#    3. Single Rule (Best: anom_swh_p80_swan): F1 = 0.230
# ✅ Saved simplified summary: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g3/confusion_matrix_summary.csv
#
# ✅ CORRECTED confusion matrix comparison analysis complete!
# ================================================================================

# %%
# %env PYTHONPATH=.
# %env RUN_PATH=run_g7
# %env MIN_DAYS=1
# !python3 scripts/plot_observed_loss_distribution.py
# Out:
# env: PYTHONPATH=.
# env: RUN_PATH=run_g7
# env: MIN_DAYS=1
# ✅ Using centralized configuration
# 🔍 OBSERVED LOSS DISTRIBUTION ANALYSIS (SIMPLIFIED)
# ============================================================
# 📍 Analyzing: CALETA_SAN_ANDRES (run_g7)
# 📁 Results directory: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7
# 📅 Found observed losses file: observed_yearly_losses_p75_20250709_235447.csv
# ✅ Loaded 7 years of observed losses
#    Year range: 2018 - 2024
#    Loss range: $23,799 - $259,140
#
# ================================================================================
# OBSERVED LOSS DISTRIBUTION ANALYSIS
# ================================================================================
# Port: CALETA_SAN_ANDRES
# Run: run_g7
# Analysis Date: 2025-07-21 13:47:01
# --------------------------------------------------------------------------------
#
# 📊 BASIC STATISTICS:
#    Total Years Analyzed: 7
#    Total Economic Loss: $922,856
#    Average Loss per Year: $131,837
#    Median Loss: $108,416
#    Standard Deviation: $85,690
#    Coefficient of Variation: 0.65
#
# 📈 PERCENTILE ANALYSIS:
#    Minimum Loss: $23,799
#    25th Percentile: $71,396
#    75th Percentile: $194,355
#    90th Percentile: $227,409
#    95th Percentile: $243,274
#    99th Percentile: $255,967
#    Maximum Loss: $259,140
#
# 🎯 LOSS CATEGORIES:
#    Zero Loss Years: 0 (0.0%)
#    High Loss Years (>P75): 2 (28.6%)
#    Extreme Loss Years (>P90): 1 (14.3%)
#
# 📅 YEARLY BREAKDOWN:
#    2018.0: $23,799 (Low)
#    2019.0: $60,819 (Low)
#    2020.0: $108,416 (Medium)
#    2021.0: $182,456 (Medium)
#    2022.0: $206,254 (High)
#    2023.0: $259,140 (High)
#    2024.0: $81,973 (Medium)
#
# ================================================================================
#
# 📊 Creating individual plots...
# 📈 Found simple AEP: aep_curve_p75_20250709_235447.csv
# 🤖 Found ML AEP: ml_aep_curve_20250717_135923.csv
# 🔗 Found multi-condition AEP: multi_rule_aep_curve_20250718_165101.csv
# ✅ Loaded SIMPLE AEP: 4000 simulations
#    Loss range: $52,886 - $224,764
#    Mean: $127,767
# ✅ Loaded ML AEP: 4000 simulations
#    Loss range: $200,966 - $364,911
#    Mean: $283,465
# ✅ Loaded MULTI AEP: 4000 simulations
#    Loss range: $126,926 - $375,489
#    Mean: $237,145
# ✅ Saved bar chart: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/observed_losses_by_year.png
# ✅ Saved density plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/observed_loss_density.png
# ✅ Saved histogram: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/observed_loss_histogram.png
# ✅ Saved summary table: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/observed_loss_summary_table.png
# 📊 Observed losses: 7 total, 7 non-negative
# 📊 SIMPLE AEP: 4000 total, 4000 non-negative
# 📊 ML AEP: 4000 total, 4000 non-negative
# 📊 MULTI AEP: 4000 total, 4000 non-negative
# ✅ Saved comprehensive overlay plot: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/observed_vs_all_aep_methods.png
# ✅ Saved AEP methods comparison table: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/aep_methods_comparison_table.png
#
# 💾 Saving summary statistics...
# ✅ Saved summary statistics: /Users/ageidv/suyana/peru_swan/results/cv_results/run_g7/observed_loss_summary_20250721_134703.csv
#
# 🎉 Analysis completed successfully!
# 📊 Individual plots created:
#    • bar_chart: observed_losses_by_year.png
#    • density_plot: observed_loss_density.png
#    • histogram: observed_loss_histogram.png
#    • summary_table: observed_loss_summary_table.png
#    • overlay_plot: observed_vs_all_aep_methods.png
#    • comparison_table: aep_methods_comparison_table.png
# 📋 Summary: observed_loss_summary_20250721_134703.csv
#
# ============================================================
#
# 🌍 AGGREGATE ANALYSIS: All 10 Regions
# ==================================================
#
# 📊 Processing run_g1...
# Traceback (most recent call last):
#   File "/Users/ageidv/suyana/peru_swan/scripts/plot_observed_loss_distribution.py", line 912, in <module>
#     aggregate_all_regions_analysis()
#   File "/Users/ageidv/suyana/peru_swan/scripts/plot_observed_loss_distribution.py", line 639, in aggregate_all_regions_analysis
#     results_dir = config.results_output_dir
# AttributeError: module 'config' has no attribute 'results_output_dir'
